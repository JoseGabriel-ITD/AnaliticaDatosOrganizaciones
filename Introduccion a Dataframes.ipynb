# %% [markdown]
# ![](Logo3.png)

# %% [markdown]
# ![](CintillaTecNM-ITD.png)

# %% [markdown]
# # Analítica de Datos en las Organizaciones
#
# # Docente: José Gabriel Rodríguez Rivas
#
#
# # Unidad I   Introducción a los Datos
#
# ## Intrduccion a  Dataframes
#
#
# [1.1 Introduccion a **Dataframes** en Pandas](#id1)<br>
# [1.2 Cargar CSV como un dataframe](#id5)<br>
# ... [1.2.1 Añadir encabezados a dataframe](#id51)<br>
# [1.3 Indexing dataframes ](#id2)<br>
# [1.4 Copiar un dataframe](#id4)<br>
# [1.5 Consultas en un dataframe](#id6)<br>
# ... [1.5.1 Consultar especificando criterios de selección y columnas a mostrar](#id61)<br>
# ... [1.5.2 Obtener los Valores Unicos de una columna en un dataframe](#id62)<br>
# ... [1.5.3 Medir el espacio en memoria que ocupa el dataframe](#id63)<br>
# ... [1.5.4 Ejercicios de Consultas en un dataframe](#id64)<br>
# [1.6 Borrar columnas o renglones en dataframes  ](#id7)<br>
# [1.7 Agregar columnas en dataframes  ](#id8)<br>
# ...  [5.8.1  Reemplazar valores ](#id81)<br>
# [1.8 Group by dataframe](#id9)<br>
# ... [1.8.1 Ejercicios de Group By](#id91)<br>
# ... [1.8.2 Aggregación](#id92)<br>
#
# [1.9 Exportar Dataframe a CSV, Excel](#id11)<br>
#
# [1.10 Leer archivo de Excel](#id13)<br>

# %% [markdown]
# ![](Pandas_python.png)
#
# ## Pandas
#
# - Es una **biblioteca de código abierto** para Python que agrega **estructuras de datos de alto rendimiento** y **herramientas para el análisis de grandes conjuntos de datos**.
# - Las **estructuras de datos de pandas** incluyen las **series** y las estructuras **dataframes (marco de datos)**.
# - **Los dataframes son la principal estructura de pandas**.
# - Pandas es una **librería externa** y se tiene que instalar. (En el caso de Anaconda viene instalado).
# - Se importa en un programa de Python mediante la instruccion import.
# - Es convencional utilizar **import pandas as pd** para facilitar la escritura de las referencias a los componentes de pandas.

# %% [markdown]
# ##  1.1 Introducción a Dataframes en Pandas   <a id='id1'> </a>
#
# ![](dataframe.png)
#
# ### Dataframe
#
# - Un DataFrame es conceptualmente un **objeto de serie bidimensional, donde hay un índice y varias columnas de contenido**, con cada columna que tiene una etiqueta.
# - Un Dataframe es una matriz de dos ejes etiquetada. Es como una tabla de datos de Excel.
# - Se utiliza para **almacenar cualquier tipo de información**.
# - El Dataframe (marcos de datos) son la principal estructura de pandas, además de la más utilizada para el análisis de datos.
# - Loss marcos de datos se construyen fácilmente de una variedad de otras estructuras de datos y archivos externos, como archivos de Excel o achivos CSV.
# - Hay una **amplia variedad de métodos disponibles** para objetos de marcos de datos.
# - Las filas y columnas se pueden manipular de diversas maneras y los operadores están disponibles para realizar transformaciones matemáticas, de cadena y lógicas al contenido del marco de datos.
#
#
# ![](The_dataframe.png)

# %% [markdown]
# ###  Documentación de Referencia
#
# - Lista de métodos de dataframe
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %%
# Primero de bemos importar la libreria de pandas
# Es convencional utilizar import pandas as pd

import pandas as pd
import numpy as np

# %%
# En este primer ejemplo el índice lo crea automaticamente pandas y será un consecutivo
# empezando desde cero

# Referencia para la informacion
# https://imco.org.mx/wp-content/uploads/2021/04/20210304_HablemosDeIngresos_2021_Documento.pdf

Estado1 = pd.Series( {'Estado': 'Aguascalientes',
                    'AportacionesFederales': 10676000000,
                    'ParticipacionesFederales': 7158000000,
                    'RecaudacionImpuestos': 1232000000} )
Estado2 = pd.Series( {'Estado': 'Baja California',
                    'AportacionesFederales': 20518000000,
                    'ParticipacionesFederales': 19401000000,
                    'RecaudacionImpuestos': 4341000000} )
Estado3 = pd.Series( {'Estado': 'Baja California Sur',
                    'AportacionesFederales': 7173000000,
                    'ParticipacionesFederales': 4809000000,
                    'RecaudacionImpuestos': 1112000000} )
Estado4 = pd.Series( {'Estado': 'Campeche',
                    'AportacionesFederales': 8835000000,
                    'ParticipacionesFederales':  5628000000,
                    'RecaudacionImpuestos': 1663000000} )

# %%
# Estado1, Estado2

# Verificamos el tipo de cualquier serie. 
# En este caso es de tipo serie

Estado1
# Out:
# Estado                      Aguascalientes
# AportacionesFederales          10676000000
# ParticipacionesFederales        7158000000
# RecaudacionImpuestos            1232000000
# dtype: object

# %%
# Convertimos a dataframe

Ingresos = pd.DataFrame( [Estado1, Estado2, Estado3, Estado4] )
Ingresos
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000
# 3            1663000000

# %%
# Copiar las series anteriores y quitar el estado de la lista de columnas 

Estado1 = pd.Series( {'AportacionesFederales': 10676000000,
                    'ParticipacionesFederales': 7158000000,
                    'RecaudacionImpuestos': 1232000000} )
Estado2 = pd.Series( {'AportacionesFederales': 20518000000,
                    'ParticipacionesFederales': 19401000000,
                    'RecaudacionImpuestos': 4341000000} )
Estado3 = pd.Series( {'AportacionesFederales': 7173000000,
                    'ParticipacionesFederales': 4809000000,
                    'RecaudacionImpuestos': 1112000000} )
Estado4 = pd.Series( {'AportacionesFederales': 8835000000,
                    'ParticipacionesFederales':  5628000000,
                    'RecaudacionImpuestos': 1663000000} )



Ingresos = pd.DataFrame([Estado1, Estado2, Estado3, Estado4],
                        index=['Aguascalientes', 'Baja California', 'Baja California Sur', 
                              'Campeche'])

Ingresos
# Out:
#                      AportacionesFederales  ParticipacionesFederales  \
# Aguascalientes                 10676000000                7158000000
# Baja California                20518000000               19401000000
# Baja California Sur             7173000000                4809000000
# Campeche                        8835000000                5628000000
#
#                      RecaudacionImpuestos
# Aguascalientes                 1232000000
# Baja California                4341000000
# Baja California Sur            1112000000
# Campeche                       1663000000

# %% [markdown]
# ### Acesso a datos del dataframe
#
# - Se puede consultar un dataframe de pandas, ya sea **por la posición del índice o por la etiqueta de índice**.
# - Si no le das un índice a la serie o dataframe, la posición y la etiqueta son efectivamente los mismos valores.
# - **Para consultar por la etiqueta de índice**, puede utilizar **el atributo loc**.
# - **Para consultar por ubicación numérica**, a partir de cero, **utilice el atributo iloc**.
#
# ###   Atributo loc  (acceder por índice)
# - Una sola etiqueta, por ejemplo: **5** o **'a'**, (tenga en cuenta que **5** se interpreta como una etiqueta del índice y nunca como una posición entera a lo largo del índice).
# - Una lista o matriz de etiquetas, por ejemplo: **['a', 'B', 'C']**.
# - Un objeto de corte con etiquetas, por ejemplo: **'a': 'f'**.
# - Una matriz booleana de la misma longitud que el eje que se está cortando, p. **[Verdadero, Falso, Verdadero]**.
#
#
# ### Atributo iloc  (acceder por índice entero)
# - Un número entero, p. 5.
# - Una lista o matriz de enteros, p. [4, 3, 0].
# - Un objeto de segmento con enteros, p. 1:7.

# %%
# # Accedemos a la informacion del dataframe por el indice

Ingresos.iloc[1]
# Out:
# AportacionesFederales       20518000000
# ParticipacionesFederales    19401000000
# RecaudacionImpuestos         4341000000
# Name: Baja California, dtype: int64

# %%
# Accedemos a la informacion del dataframe por el indice de texto
# En este caso buscamos campeche

Ingresos.loc['Campeche']
# Out:
# AportacionesFederales       8835000000
# ParticipacionesFederales    5628000000
# RecaudacionImpuestos        1663000000
# Name: Campeche, dtype: int64

# %%
# Cuando pandas regresa un renglon como resultado, lo regresa como una serie

type(Ingresos.loc['Campeche'])
# Out:
# pandas.core.series.Series

# %%
# Especificamos una lista de valores a buscar por índice
# Observar que regresa un datafarme

Ingresos.loc[ ['Campeche', 'Aguascalientes']]
# Out:
#                 AportacionesFederales  ParticipacionesFederales  \
# Campeche                   8835000000                5628000000
# Aguascalientes            10676000000                7158000000
#
#                 RecaudacionImpuestos
# Campeche                  1663000000
# Aguascalientes            1232000000

# %%
# Podemos usar el concepto de slicing que se vio en listas para ver una sección del dataframe
Ingresos.iloc[1:3]
# Out:
#                      AportacionesFederales  ParticipacionesFederales  \
# Baja California                20518000000               19401000000
# Baja California Sur             7173000000                4809000000
#
#                      RecaudacionImpuestos
# Baja California                4341000000
# Baja California Sur            1112000000

# %% [markdown]
# ###  Searching in both axes
#
# - DataFrame de Pandas permite seleccionar rápidamente datos basados en múltiples ejes.
# - Por ejemplo, se desea  listar la recuadación de Impuestos de Campeche.
# - Proporcionamos dos parámetros al atributo loc, **el primero es el índice de fila y el otro el nombre de columna**.

# %%
 Ingresos.loc['Campeche', 'RecaudacionImpuestos']
# Out:
# 1663000000

# %%
# Se puede usar listas para especificar que renglones y columnas se desean obtener

Ingresos.loc[['Campeche','Aguascalientes'], 
             ['AportacionesFederales', 'ParticipacionesFederales' ]]
# Out:
#                 AportacionesFederales  ParticipacionesFederales
# Campeche                   8835000000                5628000000
# Aguascalientes            10676000000                7158000000

# %%
Ingresos.iloc[1:3, 1]
# Out:
# Baja California        19401000000
# Baja California Sur     4809000000
# Name: ParticipacionesFederales, dtype: int64

# %%
Ingresos.iloc[1:3, 1:2]
# Out:
#                      ParticipacionesFederales
# Baja California                   19401000000
# Baja California Sur                4809000000

# %% [markdown]
# ##   1.2 Cargar CSV como un dataframe  <a id='id5'> </a>
#
# - Lea un archivo de valores separados por comas (csv) en DataFrame.
# - También admite, opcionalmente, iterar o dividir el archivo en fragmentos.

# %%
df = pd.read_csv("20-07-31-COVID19MEXICO-codificado.csv")
df
# Out:
# C:\Users\jgab\AppData\Local\Temp\ipykernel_16988\2981700023.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("20-07-31-COVID19MEXICO-codificado.csv")
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 0               31/07/2020      15f43a       2       4           2   Mujer
# 1               31/07/2020      0d6511       2       4          11  Hombre
# 2               31/07/2020      0baff6       2       9           9   Mujer
# 3               31/07/2020      1b5b75       2       9           9   Mujer
# 4               31/07/2020      120290       2       9          15   Mujer
# ...                    ...         ...     ...     ...         ...     ...
# 984283          31/07/2020      0fff21       1       4          32   Mujer
# 984284          31/07/2020      118a72       2      12          10   Mujer
# 984285          31/07/2020      09010e       1      12          32   Mujer
# 984286          31/07/2020      1d5f85       1      12          14  Hombre
# 984287          31/07/2020      17ecb4       1       4           1  Hombre
#
#             ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0       No especificado            2              4    Ambulatorio  ...
# 1       No especificado           11             20    Ambulatorio  ...
# 2       No especificado            9             16    Ambulatorio  ...
# 3       No especificado           15             37    Ambulatorio  ...
# 4       No especificado           15             37    Ambulatorio  ...
# ...                 ...          ...            ...            ...  ...
# 984283        Zacatecas           32             42  Hospitalizado  ...
# 984284        Zacatecas           10              5  Hospitalizado  ...
# 984285        Zacatecas           32             56  Hospitalizado  ...
# 984286        Zacatecas           14             39  Hospitalizado  ...
# 984287        Zacatecas            1              1  Hospitalizado  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 0                  No       No            No         No  No especificado
# 1                  No       No            No         No  No especificado
# 2                  No       No            No         No               Si
# 3                  Si       No            No         No               No
# 4                  No       No            No         No               No
# ...               ...      ...           ...        ...              ...
# 984283             No       No            No         No  No especificado
# 984284             No       No            No         No               Si
# 984285             No       No            No         No  No especificado
# 984286             No       Si            No         No               No
# 984287             No       No            No         No  No especificado
#
#         RESULTADO  MIGRANTE           PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 0        Positivo        99                 El Salvador          99  No aplica
# 1        Positivo        99  Estados Unidos de AmÃ©rica          99  No aplica
# 2        Positivo        99                      Brasil          99  No aplica
# 3        Positivo        99                     EspaÃ±a          99  No aplica
# 4        Positivo         2                   Argentina          99  No aplica
# ...           ...       ...                         ...         ...        ...
# 984283  Pendiente        99                     MÃ©xico          99         No
# 984284  Pendiente        99                     MÃ©xico          99         No
# 984285  Pendiente        99                     MÃ©xico          99         Si
# 984286  Pendiente        99                     MÃ©xico          99         Si
# 984287  Pendiente        99                     MÃ©xico          99         No
#
# [984288 rows x 35 columns]

# %% [markdown]
# ### Tipo de Datos
#
# - Los datos se encuentran en una variedad de tipos.
# - Los tipos principales almacenados en dataframes de Pandas son <b>object</b>, <b>float</b>, <b>int</b>, <b>bool</b> y <b>datetime64</b>.
# - Para aprender mejor acerca de cada atributo es mejor para nosotros saber el tipo de dato de cada columna.
# - En Pandas, podemos usar el atributo **df.dtypes**.

# %%
df.dtypes
# Out:
# FECHA_ACTUALIZACION    object
# ID_REGISTRO            object
# ORIGEN                  int64
# SECTOR                  int64
# ENTIDAD_UM              int64
# SEXO                   object
# ENTIDAD_NAC            object
# ENTIDAD_RES             int64
# MUNICIPIO_RES           int64
# TIPO_PACIENTE          object
# FECHA_INGRESO          object
# FECHA_SINTOMAS         object
# FECHA_DEF              object
# INTUBADO               object
# NEUMONIA               object
# EDAD                    int64
# NACIONALIDAD            int64
# EMBARAZO               object
# HABLA_LENGUA_INDIG     object
# DIABETES               object
# EPOC                   object
# ASMA                   object
# INMUSUPR               object
# HIPERTENSION           object
# OTRA_COM               object
# CARDIOVASCULAR         object
# OBESIDAD               object
# RENAL_CRONICA          object
# TABAQUISMO             object
# OTRO_CASO              object
# RESULTADO              object
# MIGRANTE                int64
# PAIS_NACIONALIDAD      object
# PAIS_ORIGEN            object
# UCI                    object
# dtype: object

# %% [markdown]
# ### Info (método)
#
# - Otro método que puede usar para revisar el dataframe es:
# - Este método imprime información sobre un DataFrame, incluido el tipo de índice y las columnas, los valores no nulos y el uso de la memoria.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984288 entries, 0 to 984287
# Data columns (total 35 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  984288 non-null  object
#  1   ID_REGISTRO          984288 non-null  object
#  2   ORIGEN               984288 non-null  int64
#  3   SECTOR               984288 non-null  int64
#  4   ENTIDAD_UM           984288 non-null  int64
#  5   SEXO                 984288 non-null  object
#  6   ENTIDAD_NAC          984288 non-null  object
#  7   ENTIDAD_RES          984288 non-null  int64
#  8   MUNICIPIO_RES        984288 non-null  int64
#  9   TIPO_PACIENTE        984288 non-null  object
#  10  FECHA_INGRESO        984288 non-null  object
#  11  FECHA_SINTOMAS       984288 non-null  object
#  12  FECHA_DEF            984288 non-null  object
#  13  INTUBADO             984288 non-null  object
#  14  NEUMONIA             984288 non-null  object
#  15  EDAD                 984288 non-null  int64
#  16  NACIONALIDAD         984288 non-null  int64
#  17  EMBARAZO             984288 non-null  object
#  18  HABLA_LENGUA_INDIG   984288 non-null  object
#  19  DIABETES             984288 non-null  object
#  20  EPOC                 984288 non-null  object
#  21  ASMA                 984288 non-null  object
#  22  INMUSUPR             984288 non-null  object
#  23  HIPERTENSION         984288 non-null  object
#  24  OTRA_COM             984288 non-null  object
#  25  CARDIOVASCULAR       984288 non-null  object
#  26  OBESIDAD             984288 non-null  object
#  27  RENAL_CRONICA        984288 non-null  object
#  28  TABAQUISMO           984288 non-null  object
#  29  OTRO_CASO            984288 non-null  object
#  30  RESULTADO            984288 non-null  object
#  31  MIGRANTE             984288 non-null  int64
#  32  PAIS_NACIONALIDAD    984288 non-null  object
#  33  PAIS_ORIGEN          984288 non-null  object
#  34  UCI                  984288 non-null  object
# dtypes: int64(8), object(27)
# memory usage: 262.8+ MB

# %% [markdown]
# ### Métodos head() y tail()
#
# Después de leer el conjunto de datos podemos utilizar los siguientes 2 métodos:
#
# - **head(n)** para revisar las primeras n filas del dataframe; donde n es u entero.
# - **tail(n)** mostrará las n filas del final del dataframe.

# %%
# Mostrar los primeros 5 renglones
df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 0          31/07/2020      15f43a       2       4           2   Mujer
# 1          31/07/2020      0d6511       2       4          11  Hombre
# 2          31/07/2020      0baff6       2       9           9   Mujer
# 3          31/07/2020      1b5b75       2       9           9   Mujer
# 4          31/07/2020      120290       2       9          15   Mujer
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES TIPO_PACIENTE  ...  \
# 0  No especificado            2              4   Ambulatorio  ...
# 1  No especificado           11             20   Ambulatorio  ...
# 2  No especificado            9             16   Ambulatorio  ...
# 3  No especificado           15             37   Ambulatorio  ...
# 4  No especificado           15             37   Ambulatorio  ...
#
#   CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 0             No       No            No         No  No especificado
# 1             No       No            No         No  No especificado
# 2             No       No            No         No               Si
# 3             Si       No            No         No               No
# 4             No       No            No         No               No
#
#    RESULTADO  MIGRANTE           PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 0   Positivo        99                 El Salvador          99  No aplica
# 1   Positivo        99  Estados Unidos de AmÃ©rica          99  No aplica
# 2   Positivo        99                      Brasil          99  No aplica
# 3   Positivo        99                     EspaÃ±a          99  No aplica
# 4   Positivo         2                   Argentina          99  No aplica
#
# [5 rows x 35 columns]

# %%
# Mostrar los últimos  5 renglones
df.tail()
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 984283          31/07/2020      0fff21       1       4          32   Mujer
# 984284          31/07/2020      118a72       2      12          10   Mujer
# 984285          31/07/2020      09010e       1      12          32   Mujer
# 984286          31/07/2020      1d5f85       1      12          14  Hombre
# 984287          31/07/2020      17ecb4       1       4           1  Hombre
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 984283   Zacatecas           32             42  Hospitalizado  ...
# 984284   Zacatecas           10              5  Hospitalizado  ...
# 984285   Zacatecas           32             56  Hospitalizado  ...
# 984286   Zacatecas           14             39  Hospitalizado  ...
# 984287   Zacatecas            1              1  Hospitalizado  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 984283             No       No            No         No  No especificado
# 984284             No       No            No         No               Si
# 984285             No       No            No         No  No especificado
# 984286             No       Si            No         No               No
# 984287             No       No            No         No  No especificado
#
#         RESULTADO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 984283  Pendiente        99           MÃ©xico          99  No
# 984284  Pendiente        99           MÃ©xico          99  No
# 984285  Pendiente        99           MÃ©xico          99  Si
# 984286  Pendiente        99           MÃ©xico          99  Si
# 984287  Pendiente        99           MÃ©xico          99  No
#
# [5 rows x 35 columns]

# %%
##   shape   Devuelve una tupla que representa la dimensionalidad del DataFrame

df.shape
# Out:
# (984288, 35)

# %% [markdown]
# ### 5.5.1  Añadir encabezados a dataframe <a id='id51'> </a>

# %%
# Notese que el archivo csv no tiene encabezados y el dataframe pone como
# encabezados los datos que aparecen en el primer renglón

DiagnosticoIMCO_NoHeaders = pd.read_csv("DiagnosticoIMCO_NoHeaders.csv")
DiagnosticoIMCO_NoHeaders.head()
# Out:
#      Aguascalientes  10,676,000,000   7,158,000,000   1,232,000,000  \
# 0        Guanajuato  30,265,000,000  29,097,000,000   4,373,000,000
# 1         Queretaro  12,321,000,000  11,162,000,000   2,852,000,000
# 2   San Luis Potosi  20,428,000,000  13,656,000,000   1,937,000,000
# 3         Zacatecas  14,101,000,000   7,903,000,000   1,192,000,000
# 4  Ciudad de México  16,205,000,000  68,270,000,000  58,800,000,000
#
#    Centro-Norte
# 0  Centro-Norte
# 1  Centro-Norte
# 2  Centro-Norte
# 3  Centro-Norte
# 4    Centro-Sur

# %%
# creamos una lista con los valores de los encabezados 

encabezados = ["Estado", "AportacionesFederales", "ParticipacionesFederales",
           "RecaudacionImpuestos", "Region" ]


print(encabezados)
# Out:
# ['Estado', 'AportacionesFederales', 'ParticipacionesFederales', 'RecaudacionImpuestos', 'Region']

# %%
#  Opcion 1, especificar los encabezados al abrir e archivo
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

DiagnosticoIMCO_NoHeaders = pd.read_csv("DiagnosticoIMCO_NoHeaders.csv", names=encabezados)
DiagnosticoIMCO_NoHeaders.head()
# Out:
#             Estado AportacionesFederales ParticipacionesFederales  \
# 0   Aguascalientes        10,676,000,000            7,158,000,000
# 1       Guanajuato        30,265,000,000           29,097,000,000
# 2        Queretaro        12,321,000,000           11,162,000,000
# 3  San Luis Potosi        20,428,000,000           13,656,000,000
# 4        Zacatecas        14,101,000,000            7,903,000,000
#
#   RecaudacionImpuestos        Region
# 0        1,232,000,000  Centro-Norte
# 1        4,373,000,000  Centro-Norte
# 2        2,852,000,000  Centro-Norte
# 3        1,937,000,000  Centro-Norte
# 4        1,192,000,000  Centro-Norte

# %%
# opcion 2, especificar encabezados despues de abrir el archivo

DiagnosticoIMCO_NoHeaders = pd.read_csv("DiagnosticoIMCO_NoHeaders.csv", header = None)
DiagnosticoIMCO_NoHeaders.head()
# Out:
#                  0               1               2              3  \
# 0   Aguascalientes  10,676,000,000   7,158,000,000  1,232,000,000
# 1       Guanajuato  30,265,000,000  29,097,000,000  4,373,000,000
# 2        Queretaro  12,321,000,000  11,162,000,000  2,852,000,000
# 3  San Luis Potosi  20,428,000,000  13,656,000,000  1,937,000,000
# 4        Zacatecas  14,101,000,000   7,903,000,000  1,192,000,000
#
#               4
# 0  Centro-Norte
# 1  Centro-Norte
# 2  Centro-Norte
# 3  Centro-Norte
# 4  Centro-Norte

# %%
DiagnosticoIMCO_NoHeaders.columns = encabezados

DiagnosticoIMCO_NoHeaders.head()
# Out:
#             Estado AportacionesFederales ParticipacionesFederales  \
# 0   Aguascalientes        10,676,000,000            7,158,000,000
# 1       Guanajuato        30,265,000,000           29,097,000,000
# 2        Queretaro        12,321,000,000           11,162,000,000
# 3  San Luis Potosi        20,428,000,000           13,656,000,000
# 4        Zacatecas        14,101,000,000            7,903,000,000
#
#   RecaudacionImpuestos        Region
# 0        1,232,000,000  Centro-Norte
# 1        4,373,000,000  Centro-Norte
# 2        2,852,000,000  Centro-Norte
# 3        1,937,000,000  Centro-Norte
# 4        1,192,000,000  Centro-Norte

# %% [markdown]
# ##  1.3 Indexing dataframes   <a id='id2'> </a>
#
# - El índice es el modo de acceso a un valor en Series y dataframes. Algo así como los nombres de celdas (A1, B2, etc) en Excel para acceder a un valor específico.
# - Podemos modificar el valor del índice que se asignó por defecto
# - Establecer una columna como índice, permite seleccionar más fácil un valor(es) a buscar
# - Se establece un indice con el comando **set_index()**.
# - **set_index()** es un proceso destructivo, no mantiene el índice actual (En versiones anteriores de Pandas).
# - Si quieres mantener el index actual, necesitas crear manualmente una nueva columna y copiar en ella los valores desde el atributo index.

# %%
# Volvemos a copiar el primer dataframe

Estado1 = pd.Series( {'Estado': 'Aguascalientes',
                    'AportacionesFederales': 10676000000,
                    'ParticipacionesFederales': 7158000000,
                    'RecaudacionImpuestos': 1232000000} )
Estado2 = pd.Series( {'Estado': 'Baja California',
                    'AportacionesFederales': 20518000000,
                    'ParticipacionesFederales': 19401000000,
                    'RecaudacionImpuestos': 4341000000} )
Estado3 = pd.Series( {'Estado': 'Baja California Sur',
                    'AportacionesFederales': 7173000000,
                    'ParticipacionesFederales': 4809000000,
                    'RecaudacionImpuestos': 1112000000} )
Estado4 = pd.Series( {'Estado': 'Campeche',
                    'AportacionesFederales': 8835000000,
                    'ParticipacionesFederales':  5628000000,
                    'RecaudacionImpuestos': 1663000000} )

# %%
# Observar que el indice es numérico y se generó automáticamente al crear el dataframe
#

Ingresos = pd.DataFrame( [Estado1, Estado2, Estado3, Estado4] )
Ingresos
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000
# 3            1663000000

# %%
# Podemos indicar la columna estado como índce para que sea más fácil las búsquedas

Ingresos = Ingresos.set_index('Estado')
Ingresos
# Out:
#                      AportacionesFederales  ParticipacionesFederales  \
# Estado
# Aguascalientes                 10676000000                7158000000
# Baja California                20518000000               19401000000
# Baja California Sur             7173000000                4809000000
# Campeche                        8835000000                5628000000
#
#                      RecaudacionImpuestos
# Estado
# Aguascalientes                 1232000000
# Baja California                4341000000
# Baja California Sur            1112000000
# Campeche                       1663000000

# %%
Ingresos.loc['Campeche']
# Out:
# AportacionesFederales       8835000000
# ParticipacionesFederales    5628000000
# RecaudacionImpuestos        1663000000
# Name: Campeche, dtype: int64

# %%
Ingresos.loc['Campeche', 'RecaudacionImpuestos']
# Out:
# 1663000000

# %%
Ingresos.loc[ ['Campeche', 'Aguascalientes']]
# Out:
#                 AportacionesFederales  ParticipacionesFederales  \
# Estado
# Campeche                   8835000000                5628000000
# Aguascalientes            10676000000                7158000000
#
#                 RecaudacionImpuestos
# Estado
# Campeche                  1663000000
# Aguascalientes            1232000000

# %% [markdown]
# ##  Cambiar índice

# %%
medallero = pd.read_csv("MedallasOlimpiadas2020_10.csv")
medallero
# Out:
#    Posicion              Pais  Oro  Plata  Bronce  Total
# 0         1    Estados Unidos   39     41      33    113
# 1         2             China   38     32      18     88
# 2         3             Japón   27     14      17     58
# 3         4       Reino Unido   22     21      22     65
# 4         5             Rusia   20     28      23     71
# 5         6         Australia   17      7      22     46
# 6         7  los Países Bajos   10     12      14     36
# 7         8           Francia   10     12      11     33
# 8         9          Alemania   10     11      16     37
# 9        10            Italia   10     10      20     40

# %%
medallero.set_index("Pais")
# Out:
#                   Posicion  Oro  Plata  Bronce  Total
# Pais
# Estados Unidos           1   39     41      33    113
# China                    2   38     32      18     88
# Japón                    3   27     14      17     58
# Reino Unido              4   22     21      22     65
# Rusia                    5   20     28      23     71
# Australia                6   17      7      22     46
# los Países Bajos         7   10     12      14     36
# Francia                  8   10     12      11     33
# Alemania                 9   10     11      16     37
# Italia                  10   10     10      20     40

# %%
medallero.set_index("Posicion")
# Out:
#                       Pais  Oro  Plata  Bronce  Total
# Posicion
# 1           Estados Unidos   39     41      33    113
# 2                    China   38     32      18     88
# 3                    Japón   27     14      17     58
# 4              Reino Unido   22     21      22     65
# 5                    Rusia   20     28      23     71
# 6                Australia   17      7      22     46
# 7         los Países Bajos   10     12      14     36
# 8                  Francia   10     12      11     33
# 9                 Alemania   10     11      16     37
# 10                  Italia   10     10      20     40

# %%
medallero.set_index("Total")
# Out:
#        Posicion              Pais  Oro  Plata  Bronce
# Total
# 113           1    Estados Unidos   39     41      33
# 88            2             China   38     32      18
# 58            3             Japón   27     14      17
# 65            4       Reino Unido   22     21      22
# 71            5             Rusia   20     28      23
# 46            6         Australia   17      7      22
# 36            7  los Países Bajos   10     12      14
# 33            8           Francia   10     12      11
# 37            9          Alemania   10     11      16
# 40           10            Italia   10     10      20

# %%
medallero

# Notese que aunque establecimos el índice en diferentes columnas en las celdas anteriores,
# en realidad no se hace sobre el dataframe original como podemos observar si volvemos
# a llamar al medallero. 
# por lo tanto, en los casos anteriores el resultado fue una copoia
# Out:
#    Posicion              Pais  Oro  Plata  Bronce  Total
# 0         1    Estados Unidos   39     41      33    113
# 1         2             China   38     32      18     88
# 2         3             Japón   27     14      17     58
# 3         4       Reino Unido   22     21      22     65
# 4         5             Rusia   20     28      23     71
# 5         6         Australia   17      7      22     46
# 6         7  los Países Bajos   10     12      14     36
# 7         8           Francia   10     12      11     33
# 8         9          Alemania   10     11      16     37
# 9        10            Italia   10     10      20     40

# %%
# Para que surta el cambio de inmediato, debemos especificar el atributo inplace = True

medallero.set_index("Pais", inplace=True)

# %%
medallero
# Out:
#                   Posicion  Oro  Plata  Bronce  Total
# Pais
# Estados Unidos           1   39     41      33    113
# China                    2   38     32      18     88
# Japón                    3   27     14      17     58
# Reino Unido              4   22     21      22     65
# Rusia                    5   20     28      23     71
# Australia                6   17      7      22     46
# los Países Bajos         7   10     12      14     36
# Francia                  8   10     12      11     33
# Alemania                 9   10     11      16     37
# Italia                  10   10     10      20     40

# %%
# Si reseteamos el indice, debemos colocar inplace = True
# Ver lo que pasa si no se especifica inplace

medallero.reset_index()
# Out:
#                Pais  Posicion  Oro  Plata  Bronce  Total
# 0    Estados Unidos         1   39     41      33    113
# 1             China         2   38     32      18     88
# 2             Japón         3   27     14      17     58
# 3       Reino Unido         4   22     21      22     65
# 4             Rusia         5   20     28      23     71
# 5         Australia         6   17      7      22     46
# 6  los Países Bajos         7   10     12      14     36
# 7           Francia         8   10     12      11     33
# 8          Alemania         9   10     11      16     37
# 9            Italia        10   10     10      20     40

# %%
# Ver lo que pasa si no se especifica inplace
medallero
# Out:
#                   Posicion  Oro  Plata  Bronce  Total
# Pais
# Estados Unidos           1   39     41      33    113
# China                    2   38     32      18     88
# Japón                    3   27     14      17     58
# Reino Unido              4   22     21      22     65
# Rusia                    5   20     28      23     71
# Australia                6   17      7      22     46
# los Países Bajos         7   10     12      14     36
# Francia                  8   10     12      11     33
# Alemania                 9   10     11      16     37
# Italia                  10   10     10      20     40

# %%
# Ahora con inplace

medallero.reset_index(inplace = True)

# %%
medallero
# Out:
#                Pais  Posicion  Oro  Plata  Bronce  Total
# 0    Estados Unidos         1   39     41      33    113
# 1             China         2   38     32      18     88
# 2             Japón         3   27     14      17     58
# 3       Reino Unido         4   22     21      22     65
# 4             Rusia         5   20     28      23     71
# 5         Australia         6   17      7      22     46
# 6  los Países Bajos         7   10     12      14     36
# 7           Francia         8   10     12      11     33
# 8          Alemania         9   10     11      16     37
# 9            Italia        10   10     10      20     40

# %% [markdown]
# ##  1.4 Copiar un dataframe   <a id='id4'> </a>
#
# > **DataFrame.copy(deep=True)**
#
# - **copy** Hace una copia de los índices y datos de este objeto.
#
# - Cuando **deep=True** (predeterminado), se **creará un nuevo objeto con una copia de los datos e índices del objeto que llama**. Las modificaciones a los datos o índices de la copia no se reflejarán en el objeto original (ver notas a continuación).
#
# - Cuando **deep=False**, se creará un **nuevo objeto sin copiar los datos o el índice** del objeto que llama (solo se copian las referencias a los datos y el índice). Cualquier cambio en los datos del original se reflejará en la copia superficial (y viceversa).

# %%
Ingresos
# Out:
#                      AportacionesFederales  ParticipacionesFederales  \
# Estado
# Aguascalientes                 10676000000                7158000000
# Baja California                20518000000               19401000000
# Baja California Sur             7173000000                4809000000
# Campeche                        8835000000                5628000000
#
#                      RecaudacionImpuestos
# Estado
# Aguascalientes                 1232000000
# Baja California                4341000000
# Baja California Sur            1112000000
# Campeche                       1663000000

# %%
IngresosCopia = Ingresos.copy()
IngresosCopia
# Out:
#                      AportacionesFederales  ParticipacionesFederales  \
# Estado
# Aguascalientes                 10676000000                7158000000
# Baja California                20518000000               19401000000
# Baja California Sur             7173000000                4809000000
# Campeche                        8835000000                5628000000
#
#                      RecaudacionImpuestos
# Estado
# Aguascalientes                 1232000000
# Baja California                4341000000
# Baja California Sur            1112000000
# Campeche                       1663000000

# %% [markdown]
# ## 1.5 Consultas en un dataframe  <a id='id6'> </a>
#
# - Las consultas en dataframes se realizan usando el **enmascaramiento booleano**.
# - El enmascaramiento booleano provoca que las consultas sean más rápidas y eficientes en Numpy.
# - Una **máscara booleana es una matriz que puede ser de una dimensión** (una series) , o **dos dimensiones (dataframe)**, donde cada uno de los valores de la matriz es verdadero o falso.
# - Esta **matriz se superpone** esencialmente **sobre la estructura de datos** que estamos consultando, y **cualquier celda alineada con el valor verdadero sera admitida en nuestro resultado final, y cualquier signo alineado con un valor falso no sera admitido**.
# - El enmascaramiento booleano es poderoso conceptualmente y es la piedra angular de las consultas eficientes de NumPy y Pandas.
# - Las máscaras booleanas se crean aplicando operadores directamente a la serie de pandas o objetos dataframe.

# %%
# Consultar el dataframe por sexo

# La series resultante es indexada, donde el valor de cada celda es verdadero o 
# falso, dependiendo de si el sexo de la persona es mujer o no

# El enmascaramiento en este caso lo vemos en True los que si cumplen la condicion, y False
# Los que no cumplen el criterio. 

df['SEXO'] == "Mujer"
# Out:
# 0          True
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 984283     True
# 984284     True
# 984285     True
# 984286    False
# 984287    False
# Name: SEXO, Length: 984288, dtype: bool

# %%
# Limitar con el método head() a los primeros 10 registros del dataframe

df['SEXO'].head(10) == "Mujer"
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: SEXO, dtype: bool

# %% [markdown]
# ### La funcion where
#
# - La función **where toma una mascara booleana como una condición, lo aplica al dataframe** o a la series, y **retorna una nuevo dataframe** o series de la misma forma.

# %%
# Como ya se mencionó, La función where toma una mascara booleana como una condición, 
# lo aplica al dataframe, y retorna una nuevo dataframe de la misma forma. 
# Apliquemos esta máscara booleana a los datos y creamos un dataframe de solo
# aquellas personas del sexo "Mujer"

# En el resultado podemos ver el enmascaramiento. Los que no cumplieron la condicion
# se enmascaran como un valor  NaN

# NaN, proviene del acrónimo en inglés «Not a Number» (en español: no es un número)


mujeres =df.where(df['SEXO'] == "Mujer" )
mujeres
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM   SEXO  \
# 0               31/07/2020      15f43a     2.0     4.0         2.0  Mujer
# 1                      NaN         NaN     NaN     NaN         NaN    NaN
# 2               31/07/2020      0baff6     2.0     9.0         9.0  Mujer
# 3               31/07/2020      1b5b75     2.0     9.0         9.0  Mujer
# 4               31/07/2020      120290     2.0     9.0        15.0  Mujer
# ...                    ...         ...     ...     ...         ...    ...
# 984283          31/07/2020      0fff21     1.0     4.0        32.0  Mujer
# 984284          31/07/2020      118a72     2.0    12.0        10.0  Mujer
# 984285          31/07/2020      09010e     1.0    12.0        32.0  Mujer
# 984286                 NaN         NaN     NaN     NaN         NaN    NaN
# 984287                 NaN         NaN     NaN     NaN         NaN    NaN
#
#             ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0       No especificado          2.0            4.0    Ambulatorio  ...
# 1                   NaN          NaN            NaN            NaN  ...
# 2       No especificado          9.0           16.0    Ambulatorio  ...
# 3       No especificado         15.0           37.0    Ambulatorio  ...
# 4       No especificado         15.0           37.0    Ambulatorio  ...
# ...                 ...          ...            ...            ...  ...
# 984283        Zacatecas         32.0           42.0  Hospitalizado  ...
# 984284        Zacatecas         10.0            5.0  Hospitalizado  ...
# 984285        Zacatecas         32.0           56.0  Hospitalizado  ...
# 984286              NaN          NaN            NaN            NaN  ...
# 984287              NaN          NaN            NaN            NaN  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 0                  No       No            No         No  No especificado
# 1                 NaN      NaN           NaN        NaN              NaN
# 2                  No       No            No         No               Si
# 3                  Si       No            No         No               No
# 4                  No       No            No         No               No
# ...               ...      ...           ...        ...              ...
# 984283             No       No            No         No  No especificado
# 984284             No       No            No         No               Si
# 984285             No       No            No         No  No especificado
# 984286            NaN      NaN           NaN        NaN              NaN
# 984287            NaN      NaN           NaN        NaN              NaN
#
#         RESULTADO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 0        Positivo      99.0       El Salvador          99  No aplica
# 1             NaN       NaN               NaN         NaN        NaN
# 2        Positivo      99.0            Brasil          99  No aplica
# 3        Positivo      99.0           EspaÃ±a          99  No aplica
# 4        Positivo       2.0         Argentina          99  No aplica
# ...           ...       ...               ...         ...        ...
# 984283  Pendiente      99.0           MÃ©xico          99         No
# 984284  Pendiente      99.0           MÃ©xico          99         No
# 984285  Pendiente      99.0           MÃ©xico          99         Si
# 984286        NaN       NaN               NaN         NaN        NaN
# 984287        NaN       NaN               NaN         NaN        NaN
#
# [984288 rows x 35 columns]

# %%
# La mayoría de las funciones estadísticas integradas en el objeto dataframe 
# ignoran los valores de NaN,  por eso al ejecutar una consulta a modo de
# comprobacion con el metodo count,  observamos que los NaN no forman parte de la funcion
# estadistica aplicada.

mujeres["SEXO"].count()
# Out:
# 493097

# %%
# Enseguida podemos eliminar esas filas que no tienen datos. 
# Para hacer esto, podemos usar la función dropna(). 

# Dropna se puede especificar con el atributo axis si se quiere eliminar el renglon o
# la columna. Por defecto es el renglon, por lo tanto no es necesario especificarlo


mujeres = mujeres.dropna()
mujeres
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM   SEXO  \
# 0               31/07/2020      15f43a     2.0     4.0         2.0  Mujer
# 2               31/07/2020      0baff6     2.0     9.0         9.0  Mujer
# 3               31/07/2020      1b5b75     2.0     9.0         9.0  Mujer
# 4               31/07/2020      120290     2.0     9.0        15.0  Mujer
# 7               31/07/2020      07cd25     2.0     9.0        30.0  Mujer
# ...                    ...         ...     ...     ...         ...    ...
# 984281          31/07/2020      147d41     1.0     4.0        32.0  Mujer
# 984282          31/07/2020      11b486     2.0     4.0        14.0  Mujer
# 984283          31/07/2020      0fff21     1.0     4.0        32.0  Mujer
# 984284          31/07/2020      118a72     2.0    12.0        10.0  Mujer
# 984285          31/07/2020      09010e     1.0    12.0        32.0  Mujer
#
#             ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0       No especificado          2.0            4.0    Ambulatorio  ...
# 2       No especificado          9.0           16.0    Ambulatorio  ...
# 3       No especificado         15.0           37.0    Ambulatorio  ...
# 4       No especificado         15.0           37.0    Ambulatorio  ...
# 7       No especificado         30.0           68.0    Ambulatorio  ...
# ...                 ...          ...            ...            ...  ...
# 984281        Zacatecas         32.0           10.0  Hospitalizado  ...
# 984282        Zacatecas         14.0           98.0  Hospitalizado  ...
# 984283        Zacatecas         32.0           42.0  Hospitalizado  ...
# 984284        Zacatecas         10.0            5.0  Hospitalizado  ...
# 984285        Zacatecas         32.0           56.0  Hospitalizado  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 0                  No       No            No         No  No especificado
# 2                  No       No            No         No               Si
# 3                  Si       No            No         No               No
# 4                  No       No            No         No               No
# 7                  No       No            No         No               No
# ...               ...      ...           ...        ...              ...
# 984281             No       No            No         No  No especificado
# 984282             No       No            No         Si  No especificado
# 984283             No       No            No         No  No especificado
# 984284             No       No            No         No               Si
# 984285             No       No            No         No  No especificado
#
#         RESULTADO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 0        Positivo      99.0       El Salvador          99  No aplica
# 2        Positivo      99.0            Brasil          99  No aplica
# 3        Positivo      99.0           EspaÃ±a          99  No aplica
# 4        Positivo       2.0         Argentina          99  No aplica
# 7        Positivo       2.0          Colombia          99  No aplica
# ...           ...       ...               ...         ...        ...
# 984281  Pendiente      99.0           MÃ©xico          99         No
# 984282  Pendiente      99.0           MÃ©xico          99         No
# 984283  Pendiente      99.0           MÃ©xico          99         No
# 984284  Pendiente      99.0           MÃ©xico          99         No
# 984285  Pendiente      99.0           MÃ©xico          99         Si
#
# [493097 rows x 35 columns]

# %% [markdown]
# ### Atajo más rápido para consultas o método abreviado
#
# - Actualmente **no tenemos que usar la función where explícitamente**.
# - pandas permite al operador de indexación tomar una mascara booleana como un valor en lugar de solo una lista de nombres de columnas.
# - **La sintaxis puede parecer un poco desordenada**, especialmente si no estás acostumbrado a programar lenguajes con operadores sobrecargados, pero el resultado es que puede filtrar y reducir los dataframes con relativa rapidez.
# - Aquí se prsentará un ejemplo más conciso de cómo podríamos consultar este dataframe.
# - Notará que **no hay NaNs cuando consulta el dataframe de esta manera. pandas automáticamente filtra las salidas de las filas con valores**.

# %%
#  Version con where 
# mujeres =df.where(df['SEXO'] == "Mujer" )

# Version simplificada
mujeres2 = df[ df['SEXO'] == "Mujer" ]
mujeres2
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM   SEXO  \
# 0               31/07/2020      15f43a       2       4           2  Mujer
# 2               31/07/2020      0baff6       2       9           9  Mujer
# 3               31/07/2020      1b5b75       2       9           9  Mujer
# 4               31/07/2020      120290       2       9          15  Mujer
# 7               31/07/2020      07cd25       2       9          30  Mujer
# ...                    ...         ...     ...     ...         ...    ...
# 984281          31/07/2020      147d41       1       4          32  Mujer
# 984282          31/07/2020      11b486       2       4          14  Mujer
# 984283          31/07/2020      0fff21       1       4          32  Mujer
# 984284          31/07/2020      118a72       2      12          10  Mujer
# 984285          31/07/2020      09010e       1      12          32  Mujer
#
#             ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0       No especificado            2              4    Ambulatorio  ...
# 2       No especificado            9             16    Ambulatorio  ...
# 3       No especificado           15             37    Ambulatorio  ...
# 4       No especificado           15             37    Ambulatorio  ...
# 7       No especificado           30             68    Ambulatorio  ...
# ...                 ...          ...            ...            ...  ...
# 984281        Zacatecas           32             10  Hospitalizado  ...
# 984282        Zacatecas           14             98  Hospitalizado  ...
# 984283        Zacatecas           32             42  Hospitalizado  ...
# 984284        Zacatecas           10              5  Hospitalizado  ...
# 984285        Zacatecas           32             56  Hospitalizado  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 0                  No       No            No         No  No especificado
# 2                  No       No            No         No               Si
# 3                  Si       No            No         No               No
# 4                  No       No            No         No               No
# 7                  No       No            No         No               No
# ...               ...      ...           ...        ...              ...
# 984281             No       No            No         No  No especificado
# 984282             No       No            No         Si  No especificado
# 984283             No       No            No         No  No especificado
# 984284             No       No            No         No               Si
# 984285             No       No            No         No  No especificado
#
#         RESULTADO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 0        Positivo        99       El Salvador          99  No aplica
# 2        Positivo        99            Brasil          99  No aplica
# 3        Positivo        99           EspaÃ±a          99  No aplica
# 4        Positivo         2         Argentina          99  No aplica
# 7        Positivo         2          Colombia          99  No aplica
# ...           ...       ...               ...         ...        ...
# 984281  Pendiente        99           MÃ©xico          99         No
# 984282  Pendiente        99           MÃ©xico          99         No
# 984283  Pendiente        99           MÃ©xico          99         No
# 984284  Pendiente        99           MÃ©xico          99         No
# 984285  Pendiente        99           MÃ©xico          99         Si
#
# [493097 rows x 35 columns]

# %% [markdown]
# ### Condiciones mas complejas usando los operadores AND y OR
#
# - Operador **AND**  &  (Todas las condiciones unidas por un AND se deben cumplir)
# - Operador **OR**   | (Cualquiera de las condiciones unidas por un OR se deben cumplir)

# %%
# Aqui estamos creando un nuevo dataframe (PruebasDgo a partir de una consulta)
# Con los criterios:  Que sea de Durango y que esté hospitalizado 

PruebasDgo = df[ ( df['ENTIDAD_NAC'] == "Durango") &
                ( df['TIPO_PACIENTE'] == "Hospitalizado") ]
PruebasDgo
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 845591          31/07/2020      0bdf07       2       3          25  Hombre
# 845592          31/07/2020      0b99e5       2       4           9   Mujer
# 845593          31/07/2020      19c52b       2       4           2  Hombre
# 845594          31/07/2020      0c2d53       2       4           8   Mujer
# 845595          31/07/2020      108217       2       4           2  Hombre
# ...                    ...         ...     ...     ...         ...     ...
# 847938          31/07/2020      1a48f4       1       4          10   Mujer
# 847939          31/07/2020      0644ae       1      12           8   Mujer
# 847940          31/07/2020      0a650c       1       4           8  Hombre
# 847941          31/07/2020      134728       2       9           8   Mujer
# 847942          31/07/2020      1095bd       1       4          10  Hombre
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 845591     Durango           25              6  Hospitalizado  ...
# 845592     Durango           15             58  Hospitalizado  ...
# 845593     Durango            2              4  Hospitalizado  ...
# 845594     Durango            8             37  Hospitalizado  ...
# 845595     Durango            2              2  Hospitalizado  ...
# ...            ...          ...            ...            ...  ...
# 847938     Durango           10              5  Hospitalizado  ...
# 847939     Durango           10             11  Hospitalizado  ...
# 847940     Durango            8             37  Hospitalizado  ...
# 847941     Durango            8             37  Hospitalizado  ...
# 847942     Durango           10             12  Hospitalizado  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 845591             No       Si            No         No  No especificado
# 845592             No       No            No         No  No especificado
# 845593             No       No            No         No  No especificado
# 845594             No       No            No         No  No especificado
# 845595             No       No            No         No  No especificado
# ...               ...      ...           ...        ...              ...
# 847938             No       Si            No         No  No especificado
# 847939             Si       No            No         No               No
# 847940             No       No            No         No  No especificado
# 847941             No       No            No         No               Si
# 847942             No       No            No         Si  No especificado
#
#         RESULTADO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 845591   Positivo        99           MÃ©xico          99  No
# 845592   Positivo        99           MÃ©xico          99  No
# 845593   Positivo        99           MÃ©xico          99  No
# 845594   Positivo        99           MÃ©xico          99  No
# 845595   Positivo        99           MÃ©xico          99  No
# ...           ...       ...               ...         ...  ..
# 847938  Pendiente        99           MÃ©xico          99  No
# 847939  Pendiente        99           MÃ©xico          99  No
# 847940  Pendiente        99           MÃ©xico          99  No
# 847941  Pendiente        99           MÃ©xico          99  Si
# 847942  Pendiente        99           MÃ©xico          99  No
#
# [2352 rows x 35 columns]

# %%
# Que sea de Durango, que esté hospitalizado y sea positivo a la prueba del COVID

PruebasDgo = df[ ( df['ENTIDAD_NAC'] == "Durango") & 
                ( df['TIPO_PACIENTE'] == "Hospitalizado") &
             ( df['RESULTADO'] == "Positivo") ]
PruebasDgo
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 845591          31/07/2020      0bdf07       2       3          25  Hombre
# 845592          31/07/2020      0b99e5       2       4           9   Mujer
# 845593          31/07/2020      19c52b       2       4           2  Hombre
# 845594          31/07/2020      0c2d53       2       4           8   Mujer
# 845595          31/07/2020      108217       2       4           2  Hombre
# ...                    ...         ...     ...     ...         ...     ...
# 847592          31/07/2020      1d09e5       1       4          10  Hombre
# 847593          31/07/2020      0bb65a       2       4          10  Hombre
# 847594          31/07/2020      0199c0       1      12           2  Hombre
# 847595          31/07/2020      0cfa6a       2       4           5   Mujer
# 847596          31/07/2020      1cb211       2       4          10  Hombre
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 845591     Durango           25              6  Hospitalizado  ...
# 845592     Durango           15             58  Hospitalizado  ...
# 845593     Durango            2              4  Hospitalizado  ...
# 845594     Durango            8             37  Hospitalizado  ...
# 845595     Durango            2              2  Hospitalizado  ...
# ...            ...          ...            ...            ...  ...
# 847592     Durango           10              7  Hospitalizado  ...
# 847593     Durango           10              7  Hospitalizado  ...
# 847594     Durango            2              2  Hospitalizado  ...
# 847595     Durango           10              7  Hospitalizado  ...
# 847596     Durango           10              7  Hospitalizado  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 845591             No       Si            No         No  No especificado
# 845592             No       No            No         No  No especificado
# 845593             No       No            No         No  No especificado
# 845594             No       No            No         No  No especificado
# 845595             No       No            No         No  No especificado
# ...               ...      ...           ...        ...              ...
# 847592             No       No            No         No  No especificado
# 847593             No       Si            No         No  No especificado
# 847594             No       No            No         No               Si
# 847595             No       No            No         No  No especificado
# 847596             No       No            No         No  No especificado
#
#         RESULTADO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 845591   Positivo        99           MÃ©xico          99  No
# 845592   Positivo        99           MÃ©xico          99  No
# 845593   Positivo        99           MÃ©xico          99  No
# 845594   Positivo        99           MÃ©xico          99  No
# 845595   Positivo        99           MÃ©xico          99  No
# ...           ...       ...               ...         ...  ..
# 847592   Positivo        99           MÃ©xico          99  No
# 847593   Positivo        99           MÃ©xico          99  No
# 847594   Positivo        99           MÃ©xico          99  No
# 847595   Positivo        99           MÃ©xico          99  No
# 847596   Positivo        99           MÃ©xico          99  No
#
# [1080 rows x 35 columns]

# %%
# juntando AND y Or

# Que sea de Durango, que esté hospitalizado y sea positivo a la prueba del COVID ó que sea
# de Zacatecas, que esté hospitalizado y sea positivo

PruebasDgo = df[ ( ( df['ENTIDAD_NAC'] == "Durango") & ( df['TIPO_PACIENTE'] == "Hospitalizado") &
             ( df['RESULTADO'] == "Positivo"))  | 
                
                ( df['ENTIDAD_NAC'] == "Zacatecas") & ( df['TIPO_PACIENTE'] == "Hospitalizado") &
             ( df['RESULTADO'] == "Positivo") ]
PruebasDgo
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 845591          31/07/2020      0bdf07       2       3          25  Hombre
# 845592          31/07/2020      0b99e5       2       4           9   Mujer
# 845593          31/07/2020      19c52b       2       4           2  Hombre
# 845594          31/07/2020      0c2d53       2       4           8   Mujer
# 845595          31/07/2020      108217       2       4           2  Hombre
# ...                    ...         ...     ...     ...         ...     ...
# 983946          31/07/2020      1727d9       1      12           2   Mujer
# 983947          31/07/2020      01cff9       1      12          32  Hombre
# 983948          31/07/2020      1d5ece       1       4          32  Hombre
# 983949          31/07/2020      087bbf       2       4          14  Hombre
# 983950          31/07/2020      186381       1      12           1  Hombre
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 845591     Durango           25              6  Hospitalizado  ...
# 845592     Durango           15             58  Hospitalizado  ...
# 845593     Durango            2              4  Hospitalizado  ...
# 845594     Durango            8             37  Hospitalizado  ...
# 845595     Durango            2              2  Hospitalizado  ...
# ...            ...          ...            ...            ...  ...
# 983946   Zacatecas            2              2  Hospitalizado  ...
# 983947   Zacatecas           32             10  Hospitalizado  ...
# 983948   Zacatecas           32             17  Hospitalizado  ...
# 983949   Zacatecas           14            120  Hospitalizado  ...
# 983950   Zacatecas            1              1  Hospitalizado  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 845591             No       Si            No         No  No especificado
# 845592             No       No            No         No  No especificado
# 845593             No       No            No         No  No especificado
# 845594             No       No            No         No  No especificado
# 845595             No       No            No         No  No especificado
# ...               ...      ...           ...        ...              ...
# 983946             No       No            No         No               Si
# 983947             No       No            No         No               No
# 983948             No       No            No         No  No especificado
# 983949             No       No            No         No  No especificado
# 983950             Si       Si            No         Si               No
#
#         RESULTADO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 845591   Positivo        99           MÃ©xico          99  No
# 845592   Positivo        99           MÃ©xico          99  No
# 845593   Positivo        99           MÃ©xico          99  No
# 845594   Positivo        99           MÃ©xico          99  No
# 845595   Positivo        99           MÃ©xico          99  No
# ...           ...       ...               ...         ...  ..
# 983946   Positivo        99           MÃ©xico          99  No
# 983947   Positivo        99           MÃ©xico          99  No
# 983948   Positivo        99           MÃ©xico          99  No
# 983949   Positivo        99           MÃ©xico          99  No
# 983950   Positivo        99           MÃ©xico          99  No
#
# [2248 rows x 35 columns]

# %%
# Otra forma de hacerlo 8 Primero el OR y lo ponemos entre paréntesis

PruebasDgo = df[ ( ( df['ENTIDAD_NAC'] == "Durango") | 
                  ( df['ENTIDAD_NAC'] == "Zacatecas") ) &
                
                  ( df['TIPO_PACIENTE'] == "Hospitalizado") &
             ( df['RESULTADO'] == "Positivo") ]
PruebasDgo
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 845591          31/07/2020      0bdf07       2       3          25  Hombre
# 845592          31/07/2020      0b99e5       2       4           9   Mujer
# 845593          31/07/2020      19c52b       2       4           2  Hombre
# 845594          31/07/2020      0c2d53       2       4           8   Mujer
# 845595          31/07/2020      108217       2       4           2  Hombre
# ...                    ...         ...     ...     ...         ...     ...
# 983946          31/07/2020      1727d9       1      12           2   Mujer
# 983947          31/07/2020      01cff9       1      12          32  Hombre
# 983948          31/07/2020      1d5ece       1       4          32  Hombre
# 983949          31/07/2020      087bbf       2       4          14  Hombre
# 983950          31/07/2020      186381       1      12           1  Hombre
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 845591     Durango           25              6  Hospitalizado  ...
# 845592     Durango           15             58  Hospitalizado  ...
# 845593     Durango            2              4  Hospitalizado  ...
# 845594     Durango            8             37  Hospitalizado  ...
# 845595     Durango            2              2  Hospitalizado  ...
# ...            ...          ...            ...            ...  ...
# 983946   Zacatecas            2              2  Hospitalizado  ...
# 983947   Zacatecas           32             10  Hospitalizado  ...
# 983948   Zacatecas           32             17  Hospitalizado  ...
# 983949   Zacatecas           14            120  Hospitalizado  ...
# 983950   Zacatecas            1              1  Hospitalizado  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 845591             No       Si            No         No  No especificado
# 845592             No       No            No         No  No especificado
# 845593             No       No            No         No  No especificado
# 845594             No       No            No         No  No especificado
# 845595             No       No            No         No  No especificado
# ...               ...      ...           ...        ...              ...
# 983946             No       No            No         No               Si
# 983947             No       No            No         No               No
# 983948             No       No            No         No  No especificado
# 983949             No       No            No         No  No especificado
# 983950             Si       Si            No         Si               No
#
#         RESULTADO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 845591   Positivo        99           MÃ©xico          99  No
# 845592   Positivo        99           MÃ©xico          99  No
# 845593   Positivo        99           MÃ©xico          99  No
# 845594   Positivo        99           MÃ©xico          99  No
# 845595   Positivo        99           MÃ©xico          99  No
# ...           ...       ...               ...         ...  ..
# 983946   Positivo        99           MÃ©xico          99  No
# 983947   Positivo        99           MÃ©xico          99  No
# 983948   Positivo        99           MÃ©xico          99  No
# 983949   Positivo        99           MÃ©xico          99  No
# 983950   Positivo        99           MÃ©xico          99  No
#
# [2248 rows x 35 columns]

# %%
# POdemos contabilizar cuantos registros existen en el dataframe
# el resultado lo genera por cada atributo o columna

PruebasDgo.count()
# Out:
# FECHA_ACTUALIZACION    2248
# ID_REGISTRO            2248
# ORIGEN                 2248
# SECTOR                 2248
# ENTIDAD_UM             2248
# SEXO                   2248
# ENTIDAD_NAC            2248
# ENTIDAD_RES            2248
# MUNICIPIO_RES          2248
# TIPO_PACIENTE          2248
# FECHA_INGRESO          2248
# FECHA_SINTOMAS         2248
# FECHA_DEF              2248
# INTUBADO               2248
# NEUMONIA               2248
# EDAD                   2248
# NACIONALIDAD           2248
# EMBARAZO               2248
# HABLA_LENGUA_INDIG     2248
# DIABETES               2248
# EPOC                   2248
# ASMA                   2248
# INMUSUPR               2248
# HIPERTENSION           2248
# OTRA_COM               2248
# CARDIOVASCULAR         2248
# OBESIDAD               2248
# RENAL_CRONICA          2248
# TABAQUISMO             2248
# OTRO_CASO              2248
# RESULTADO              2248
# MIGRANTE               2248
# PAIS_NACIONALIDAD      2248
# PAIS_ORIGEN            2248
# UCI                    2248
# dtype: int64

# %%
# Es mejor si lo hacemos sobre una columna 

PruebasDgo["ID_REGISTRO"].count()
# Out:
# 2248

# %% [markdown]
# ### 1.5.1 Consultar especificando criterios de selección y columnas a mostrar  <a id='id61'> </a>
#
# - Primero se especifican los criterios de seleccion
# - Enseguida la lista de columnas a mostrar

# %%
# Buscar los positivos y mostrar las columnas de ENTIDAD_NAC, RESULTADO y SEXO

totalcasos = df[ ( df['RESULTADO'] == "Positivo") ]  [["ENTIDAD_NAC", "RESULTADO", "SEXO" ]]                
totalcasos.head(10)
# Out:
#        ENTIDAD_NAC RESULTADO    SEXO
# 0  No especificado  Positivo   Mujer
# 1  No especificado  Positivo  Hombre
# 2  No especificado  Positivo   Mujer
# 3  No especificado  Positivo   Mujer
# 4  No especificado  Positivo   Mujer
# 5  No especificado  Positivo  Hombre
# 6  No especificado  Positivo  Hombre
# 7  No especificado  Positivo   Mujer
# 8  No especificado  Positivo  Hombre
# 9  No especificado  Positivo  Hombre

# %%
# Buscar los positivos  del estado de  Colima y mostrar las columnas de ENTIDAD_NAC, RESULTADO y SEXO

totalcasos = df[ ( df['ENTIDAD_NAC'] == "Colima") & 
                ( df['RESULTADO'] == "Positivo") ] [["ENTIDAD_NAC", "RESULTADO", "SEXO" ]]
                
totalcasos.head(10)
# Out:
#        ENTIDAD_NAC RESULTADO    SEXO
# 261336      Colima  Positivo  Hombre
# 261337      Colima  Positivo  Hombre
# 261338      Colima  Positivo  Hombre
# 261339      Colima  Positivo   Mujer
# 261340      Colima  Positivo  Hombre
# 261341      Colima  Positivo  Hombre
# 261342      Colima  Positivo  Hombre
# 261343      Colima  Positivo   Mujer
# 261344      Colima  Positivo   Mujer
# 261345      Colima  Positivo  Hombre

# %% [markdown]
# ### 1.5.2  Obtener los Valores Únicos de una columna en un dataframe <a id='id62'> </a>

# %%
#  Equivalente al distinct de SQL

df['ENTIDAD_NAC'].unique()
# Out:
# array(['No especificado', 'Aguascalientes', 'Baja California',
#        'Baja California Sur', 'Campeche', 'Chiapas', 'Chihuahua',
#        'Ciudad de México', 'Coahuila', 'Colima', 'Durango', 'Guanajuato',
#        'Guerrero', 'Hidalgo', 'Jalisco', 'México', 'Michoacan', 'Morelos',
#        'Nayarit', 'Nuevo León', 'Oaxaca', 'Puebla', 'Queretaro',
#        'Quintana Roo', 'San Luis Potosí', 'Sinaloa', 'Sonora', 'Tabasco',
#        'Tamaulipas', 'Tlaxcala', 'Veracruz', 'Yucatan', 'Zacatecas'],
#       dtype=object)

# %%
df['RESULTADO'].unique()
# Out:
# array(['Positivo', 'Negativo', 'Pendiente'], dtype=object)

# %% [markdown]
# ### 1.5.3 Medir el espacio en memoria que ocupa el dataframe  <a id='id63'> </a>

# %%
import sys
print(sys.getsizeof(df))      ## 1,733,346,211
# Out:
# 1733346211

# %%
# Megabyte es el equivalente a 1024 kilobytes o 1,048,576 bytes

megas = 1733346211 / 1048576
megas
# Out:
# 1653.0477628707886

# %% [markdown]
# ### 1.5.4 Ejercicios de consultas en el dataframe  <a id='id64'> </a>
#
# 1. Consultar en el dataframe COVID los que son de Campeche y son Positivos
# 2. Consultar en el dataframe COVID los que son de Aguascalientes y están hospitalizados
# 3. Consultar en el dataframe COVID los que son de Durango, Son positivos, tienen Obesidad, tienen diabetes y tienen hipertension
# 4. Consultar en el dataframe COVID los que son de Colima o de Morelos y que son positivos

# %%
covid = pd.read_csv("20-07-31-COVID19MEXICO-codificado.csv")
# Out:
# C:\Users\jgab\AppData\Local\Temp\ipykernel_8388\3233244115.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   covid = pd.read_csv("20-07-31-COVID19MEXICO-codificado.csv")

# %%
# Ejercicio 1

covid2 = covid[ (covid["ENTIDAD_NAC"] == "Campeche") & (covid["RESULTADO"] =="Positivo")]
covid2
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 30675           31/07/2020      1c7d68       2       4          23  Hombre
# 30676           31/07/2020      0a0f4c       2       4          31  Hombre
# 30677           31/07/2020      07fdf0       2       4           4  Hombre
# 30678           31/07/2020      09b088       2       4          31  Hombre
# 30679           31/07/2020      0fa639       2       6           4  Hombre
# ...                    ...         ...     ...     ...         ...     ...
# 802391          31/07/2020      04b1ff       2      12           4  Hombre
# 802392          31/07/2020       71176       1       6          31  Hombre
# 802393          31/07/2020      0f104b       1       4           4  Hombre
# 802394          31/07/2020    1.52E+05       1      12           4  Hombre
# 802395          31/07/2020      1401a7       1      12           4   Mujer
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 30675     Campeche           23              5    Ambulatorio  ...
# 30676     Campeche           31            101    Ambulatorio  ...
# 30677     Campeche            4              2    Ambulatorio  ...
# 30678     Campeche           31             50    Ambulatorio  ...
# 30679     Campeche            4              3    Ambulatorio  ...
# ...            ...          ...            ...            ...  ...
# 802391    Campeche            4              3  Hospitalizado  ...
# 802392    Campeche            4              1  Hospitalizado  ...
# 802393    Campeche            4              2  Hospitalizado  ...
# 802394    Campeche            4              2  Hospitalizado  ...
# 802395    Campeche            4              2  Hospitalizado  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 30675              No       Si            No         Si  No especificado
# 30676              No       Si            No         No  No especificado
# 30677              No       Si            No         No  No especificado
# 30678              No       Si            No         No  No especificado
# 30679              No       No            No         No               Si
# ...               ...      ...           ...        ...              ...
# 802391             No       Si            No         No               No
# 802392             No       Si            No         No               No
# 802393             No       No            No         No  No especificado
# 802394             No       No            No         No               No
# 802395             No       No            No         No               No
#
#         RESULTADO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 30675    Positivo        99           MÃ©xico          99  No aplica
# 30676    Positivo        99           MÃ©xico          99  No aplica
# 30677    Positivo        99           MÃ©xico          99  No aplica
# 30678    Positivo        99           MÃ©xico          99  No aplica
# 30679    Positivo        99           MÃ©xico          99  No aplica
# ...           ...       ...               ...         ...        ...
# 802391   Positivo        99           MÃ©xico          99         No
# 802392   Positivo        99           MÃ©xico          99         No
# 802393   Positivo        99           MÃ©xico          99         No
# 802394   Positivo        99           MÃ©xico          99         No
# 802395   Positivo        99           MÃ©xico          99         Si
#
# [4062 rows x 35 columns]

# %%
# Ejercicio 2

covid2 = covid[ (covid["ENTIDAD_NAC"] == "Aguascalientes") & 
               (covid["TIPO_PACIENTE"] == "Hospitalizado")]
covid2
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 795010          31/07/2020      110cc5       2       4           6  Hombre
# 795011          31/07/2020      0fb58c       2       4           1  Hombre
# 795012          31/07/2020      0b36b4       2       4           1  Hombre
# 795013          31/07/2020      163930       2       4           1  Hombre
# 795014          31/07/2020      0c0317       2       4           1   Mujer
# ...                    ...         ...     ...     ...         ...     ...
# 796477          31/07/2020      13453e       2       4          26   Mujer
# 796478          31/07/2020      1c2edc       1       4           1  Hombre
# 796479          31/07/2020      1071a9       1      12           1   Mujer
# 796480          31/07/2020      0db0c1       1       4          28   Mujer
# 796481          31/07/2020      14c350       1       4           1   Mujer
#
#            ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 795010  Aguascalientes            6              7  Hospitalizado  ...
# 795011  Aguascalientes            1              1  Hospitalizado  ...
# 795012  Aguascalientes            1              1  Hospitalizado  ...
# 795013  Aguascalientes            1              1  Hospitalizado  ...
# 795014  Aguascalientes            1             11  Hospitalizado  ...
# ...                ...          ...            ...            ...  ...
# 796477  Aguascalientes           26             30  Hospitalizado  ...
# 796478  Aguascalientes            1              1  Hospitalizado  ...
# 796479  Aguascalientes            1              3  Hospitalizado  ...
# 796480  Aguascalientes           28             38  Hospitalizado  ...
# 796481  Aguascalientes            1              1  Hospitalizado  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 795010             No       Si            No         No  No especificado
# 795011             No       No            No         No  No especificado
# 795012             No       No            No         No  No especificado
# 795013             No       No            Si         No  No especificado
# 795014             No       No            No         No  No especificado
# ...               ...      ...           ...        ...              ...
# 796477             No       No            Si         No  No especificado
# 796478             No       No            No         No  No especificado
# 796479             No       No            No         No               No
# 796480             No       Si            No         No  No especificado
# 796481             No       Si            No         No  No especificado
#
#         RESULTADO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 795010   Positivo        99           MÃ©xico          99  No
# 795011   Positivo        99           MÃ©xico          99  No
# 795012   Positivo        99           MÃ©xico          99  No
# 795013   Positivo        99           MÃ©xico          99  No
# 795014   Positivo        99           MÃ©xico          99  No
# ...           ...       ...               ...         ...  ..
# 796477  Pendiente        99           MÃ©xico          99  No
# 796478  Pendiente        99           MÃ©xico          99  No
# 796479  Pendiente        99           MÃ©xico          99  Si
# 796480  Pendiente        99           MÃ©xico          99  No
# 796481  Pendiente        99           MÃ©xico          99  No
#
# [1472 rows x 35 columns]

# %%
# Ejercicio 3

# Consultar en el dataframe COVID los que son de Durango, Son positivos, tienen Obesidad, 
#tienen diabetes y tienen hipertension

covid2 = covid[ (covid["ENTIDAD_NAC"]== "Durango") &
               (covid["RESULTADO"] == "Positivo") & 
               (covid["OBESIDAD"] == "Si") &
               ( covid["DIABETES"] == "Si") &
               (covid["HIPERTENSION"] =="Si")]

covid2
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 263778          31/07/2020      08267a       2      99          10   Mujer
# 263825          31/07/2020      145ca1       2      12           9   Mujer
# 263866          31/07/2020       18355       1       4           8   Mujer
# 263887          31/07/2020      090ac9       1       4          10  Hombre
# 264006          31/07/2020      0d79ea       2       4           5  Hombre
# ...                    ...         ...     ...     ...         ...     ...
# 847501          31/07/2020      188163       2       4           2   Mujer
# 847505          31/07/2020      12e1bb       2       4          19   Mujer
# 847507          31/07/2020      05c1a5       2       4          10  Hombre
# 847511          31/07/2020      1863bc       1      12           2  Hombre
# 847579          31/07/2020      1964eb       1       4           5   Mujer
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 263778     Durango           10             20    Ambulatorio  ...
# 263825     Durango            9              7    Ambulatorio  ...
# 263866     Durango            8             37    Ambulatorio  ...
# 263887     Durango           10              5    Ambulatorio  ...
# 264006     Durango            5             25    Ambulatorio  ...
# ...            ...          ...            ...            ...  ...
# 847501     Durango            2              4  Hospitalizado  ...
# 847505     Durango           19             39  Hospitalizado  ...
# 847507     Durango           10             23  Hospitalizado  ...
# 847511     Durango            2              1  Hospitalizado  ...
# 847579     Durango            5             25  Hospitalizado  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 263778             No       Si            No         No  No especificado
# 263825             No       Si            No         No               Si
# 263866             No       Si            No         No  No especificado
# 263887             No       Si            No         No  No especificado
# 264006             No       Si            No         No  No especificado
# ...               ...      ...           ...        ...              ...
# 847501             No       Si            No         No  No especificado
# 847505             No       Si            No         No  No especificado
# 847507             No       Si            No         No  No especificado
# 847511             No       Si            No         No               Si
# 847579             No       Si            No         No  No especificado
#
#         RESULTADO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 263778   Positivo        99           MÃ©xico          99  No aplica
# 263825   Positivo        99           MÃ©xico          99  No aplica
# 263866   Positivo        99           MÃ©xico          99  No aplica
# 263887   Positivo        99           MÃ©xico          99  No aplica
# 264006   Positivo        99           MÃ©xico          99  No aplica
# ...           ...       ...               ...         ...        ...
# 847501   Positivo        99           MÃ©xico          99         No
# 847505   Positivo        99           MÃ©xico          99         No
# 847507   Positivo        99           MÃ©xico          99         No
# 847511   Positivo        99           MÃ©xico          99         No
# 847579   Positivo        99           MÃ©xico          99         No
#
# [128 rows x 35 columns]

# %%
# Ejercicio 4

#  los que son de Colima o de Morelos y que son positivos

covid2 = covid[ ( (covid["ENTIDAD_NAC"] == "Colima") | 
               (covid["ENTIDAD_NAC"] == "Morelos") ) & (covid["RESULTADO"] == "Positivo")]

covid2
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 261336          31/07/2020      16af25       2       4           6  Hombre
# 261337          31/07/2020      1ccb6e       2       4          14  Hombre
# 261338          31/07/2020      08781c       2       4           9  Hombre
# 261339          31/07/2020      0b7401       2       4           6   Mujer
# 261340          31/07/2020      1a43d8       2       4           6  Hombre
# ...                    ...         ...     ...     ...         ...     ...
# 906661          31/07/2020      08c682       2       4          17  Hombre
# 906662          31/07/2020      101fc8       1       4          17  Hombre
# 906663          31/07/2020      0f3e9d       1      12          17  Hombre
# 906664          31/07/2020      1a4513       2      12          17   Mujer
# 906665          31/07/2020      149067       2       6          17  Hombre
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 261336      Colima            6              7    Ambulatorio  ...
# 261337      Colima           14             67    Ambulatorio  ...
# 261338      Colima            9              5    Ambulatorio  ...
# 261339      Colima            6              7    Ambulatorio  ...
# 261340      Colima            6              7    Ambulatorio  ...
# ...            ...          ...            ...            ...  ...
# 906661     Morelos           17              6  Hospitalizado  ...
# 906662     Morelos           17              7  Hospitalizado  ...
# 906663     Morelos           17              7  Hospitalizado  ...
# 906664     Morelos           17              4  Hospitalizado  ...
# 906665     Morelos           17             29  Hospitalizado  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 261336             No       No            No         No  No especificado
# 261337             No       Si            No         No  No especificado
# 261338             No       No            No         No  No especificado
# 261339             No       Si            No         No  No especificado
# 261340             No       Si            No         No  No especificado
# ...               ...      ...           ...        ...              ...
# 906661             No       No            Si         No  No especificado
# 906662             No       No            No         No  No especificado
# 906663             No       No            No         No               No
# 906664             No       No            No         No               Si
# 906665             No       No            No         No               No
#
#         RESULTADO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 261336   Positivo        99           MÃ©xico          99  No aplica
# 261337   Positivo        99           MÃ©xico          99  No aplica
# 261338   Positivo        99           MÃ©xico          99  No aplica
# 261339   Positivo        99           MÃ©xico          99  No aplica
# 261340   Positivo        99           MÃ©xico          99  No aplica
# ...           ...       ...               ...         ...        ...
# 906661   Positivo        99           MÃ©xico          99         No
# 906662   Positivo        99           MÃ©xico          99         No
# 906663   Positivo        99           MÃ©xico          99         No
# 906664   Positivo        99           MÃ©xico          99         No
# 906665   Positivo        99           MÃ©xico          99         No
#
# [5436 rows x 35 columns]

# %%
covid2.count()
# Out:
# FECHA_ACTUALIZACION    5436
# ID_REGISTRO            5436
# ORIGEN                 5436
# SECTOR                 5436
# ENTIDAD_UM             5436
# SEXO                   5436
# ENTIDAD_NAC            5436
# ENTIDAD_RES            5436
# MUNICIPIO_RES          5436
# TIPO_PACIENTE          5436
# FECHA_INGRESO          5436
# FECHA_SINTOMAS         5436
# FECHA_DEF              5436
# INTUBADO               5436
# NEUMONIA               5436
# EDAD                   5436
# NACIONALIDAD           5436
# EMBARAZO               5436
# HABLA_LENGUA_INDIG     5436
# DIABETES               5436
# EPOC                   5436
# ASMA                   5436
# INMUSUPR               5436
# HIPERTENSION           5436
# OTRA_COM               5436
# CARDIOVASCULAR         5436
# OBESIDAD               5436
# RENAL_CRONICA          5436
# TABAQUISMO             5436
# OTRO_CASO              5436
# RESULTADO              5436
# MIGRANTE               5436
# PAIS_NACIONALIDAD      5436
# PAIS_ORIGEN            5436
# UCI                    5436
# dtype: int64

# %%
covid2["ID_REGISTRO"].count()
# Out:
# 5436

# %% [markdown]
# ## 1.6 Borrar columnas o renglones en dataframes  <a id='id7'> </a>
#
# - Se usa la funcion **drop** para borrar renglones o columnas
# - La función drop no cambia el DataFrame de forma predeterminada, en su lugar, devuelve una copia del DataFrame con las filas eliminadas.
#
# **Drop** tiene dos parámetros opcionales
# - El primero se llama **in place** y si se establece en **True**, el DataFrame se actualizará en su lugar, en lugar de devolver una copia.
# - El segundo parámetro es **axis**, que especifica que se debe borrar. De forma predeterminada, este valor es **0 para borrar las filas**. Pero puede cambiarlo a **1 si desea borrar una columna**.

# %%
IngresosCopia
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000
# 3            1663000000

# %%
# Borrar el renglon con indice 3

IngresosCopia.drop(3)
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000

# %%
# El borrado lo hace en una copia y no lo borra definitivamente

IngresosCopia
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000
# 3            1663000000

# %%
# Para que el borrado sea de inmediato, debemos agregar el atributo inplace = True

IngresosCopia.drop(3, inplace= True)

# %%
# Ahora si vemos que se borro definitivamente
IngresosCopia
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000

# %%
# Si queremos borrar una columna debemos especificar que es sobre el eje 1, es decir
# sobre las columnas

IngresosCopia.drop("AportacionesFederales", axis = 1)
# Out:
#                 Estado  ParticipacionesFederales  RecaudacionImpuestos
# 0       Aguascalientes                7158000000            1232000000
# 1      Baja California               19401000000            4341000000
# 2  Baja California Sur                4809000000            1112000000

# %%
IngresosCopia
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000

# %%
# NUevamente, especificar inplace = True

IngresosCopia.drop("AportacionesFederales", axis = 1, inplace = True)

# %%
IngresosCopia
# Out:
#                 Estado  ParticipacionesFederales  RecaudacionImpuestos
# 0       Aguascalientes                7158000000            1232000000
# 1      Baja California               19401000000            4341000000
# 2  Baja California Sur                4809000000            1112000000

# %%
#   Volvemos a copiar el dataframe ingresos

IngresosCopia = Ingresos.copy()
IngresosCopia
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000
# 3            1663000000

# %%
# Es mas facil borrrar si se establece como indice el estado

IngresosCopia.set_index("Estado", inplace = True)
IngresosCopia
# Out:
#                      AportacionesFederales  ParticipacionesFederales  \
# Estado
# Aguascalientes                 10676000000                7158000000
# Baja California                20518000000               19401000000
# Baja California Sur             7173000000                4809000000
# Campeche                        8835000000                5628000000
#
#                      RecaudacionImpuestos
# Estado
# Aguascalientes                 1232000000
# Baja California                4341000000
# Baja California Sur            1112000000
# Campeche                       1663000000

# %%
IngresosCopia.drop("Baja California Sur", inplace = True)
IngresosCopia
# Out:
#                  AportacionesFederales  ParticipacionesFederales  \
# Estado
# Aguascalientes             10676000000                7158000000
# Baja California            20518000000               19401000000
# Campeche                    8835000000                5628000000
#
#                  RecaudacionImpuestos
# Estado
# Aguascalientes             1232000000
# Baja California            4341000000
# Campeche                   1663000000

# %% [markdown]
# ### Alternativa 2 de borrado de columnas de dataframes
#
# - Esta opción tiene efecto inmediato

# %%
del IngresosCopia["ParticipacionesFederales"]

# %%
IngresosCopia
# Out:
#                  AportacionesFederales  RecaudacionImpuestos
# Estado
# Aguascalientes             10676000000            1232000000
# Baja California            20518000000            4341000000
# Campeche                    8835000000            1663000000

# %% [markdown]
# ## 1.7 Agregar columnas en dataframes <a id='id8'> </a>

# %%
# Verificamos los datos actuales que tenemos en el dataframe Ingresos

Ingresos
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000
# 3            1663000000

# %%
# Agregamos una nueva columna calculada que sume las 3 columnas existentes 

# La diagonal invertida la usamos para continuar el código en otr línea

Ingresos["Total"] = Ingresos["AportacionesFederales"] + \
                    Ingresos["ParticipacionesFederales"] + \
                    Ingresos["RecaudacionImpuestos"]

# %%
Ingresos
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos        Total
# 0            1232000000  19066000000
# 1            4341000000  44260000000
# 2            1112000000  13094000000
# 3            1663000000  16126000000

# %% [markdown]
# ### 1.7.1  Reemplazar valores   <a id='id81'> </a>
#
# - En el dataset COVID necesitamos reemplazar los valores que vienen codificados como SEXO, RESULTADO, etc.

# %%
df.head(10)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 0          31/07/2020      15f43a       2       4           2   Mujer
# 1          31/07/2020      0d6511       2       4          11  Hombre
# 2          31/07/2020      0baff6       2       9           9   Mujer
# 3          31/07/2020      1b5b75       2       9           9   Mujer
# 4          31/07/2020      120290       2       9          15   Mujer
# 5          31/07/2020      0e8480       2      12           8  Hombre
# 6          31/07/2020      0d51e8       2       9          15  Hombre
# 7          31/07/2020      07cd25       2       9          30   Mujer
# 8          31/07/2020      14a0c9       2       9          28  Hombre
# 9          31/07/2020      15843c       2       9          15  Hombre
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES TIPO_PACIENTE  ...  \
# 0  No especificado            2              4   Ambulatorio  ...
# 1  No especificado           11             20   Ambulatorio  ...
# 2  No especificado            9             16   Ambulatorio  ...
# 3  No especificado           15             37   Ambulatorio  ...
# 4  No especificado           15             37   Ambulatorio  ...
# 5  No especificado            8             37   Ambulatorio  ...
# 6  No especificado           15             37   Ambulatorio  ...
# 7  No especificado           30             68   Ambulatorio  ...
# 8  No especificado           28              3   Ambulatorio  ...
# 9  No especificado           15             37   Ambulatorio  ...
#
#   CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 0             No       No            No         No  No especificado
# 1             No       No            No         No  No especificado
# 2             No       No            No         No               Si
# 3             Si       No            No         No               No
# 4             No       No            No         No               No
# 5             No       No            No         No               No
# 6             No       No            No         No               No
# 7             No       No            No         No               No
# 8             No       No            No         No               No
# 9             No       No            No         No               No
#
#    RESULTADO  MIGRANTE           PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 0   Positivo        99                 El Salvador          99  No aplica
# 1   Positivo        99  Estados Unidos de AmÃ©rica          99  No aplica
# 2   Positivo        99                      Brasil          99  No aplica
# 3   Positivo        99                     EspaÃ±a          99  No aplica
# 4   Positivo         2                   Argentina          99  No aplica
# 5   Positivo         2  Estados Unidos de AmÃ©rica          99  No aplica
# 6   Positivo         2                       Suiza          99  No aplica
# 7   Positivo         2                    Colombia          99  No aplica
# 8   Positivo        99                     Malasia          99  No aplica
# 9   Positivo         2  Estados Unidos de AmÃ©rica          99  No aplica
#
# [10 rows x 35 columns]

# %%
# Contra valores de ORIGEN

df['ORIGEN'].value_counts()
# Out:
# 2    647734
# 1    336554
# Name: ORIGEN, dtype: int64

# %%
df["ORIGEN"].replace(2, "ISSSTE")
# Out:
# 0         ISSSTE
# 1         ISSSTE
# 2         ISSSTE
# 3         ISSSTE
# 4         ISSSTE
#            ...
# 984283         1
# 984284    ISSSTE
# 984285         1
# 984286         1
# 984287         1
# Name: ORIGEN, Length: 984288, dtype: object

# %%
# Al verificar vemos que no realizo el cambio en el dataframe original

df['ORIGEN'].value_counts()
# Out:
# 2    647734
# 1    336554
# Name: ORIGEN, dtype: int64

# %%
# Volvemos a ejecutar pero ahora con inplace = True

df["ORIGEN"].replace(2, "ISSSTE", inplace = True)

# %%
df['ORIGEN'].value_counts()
# Out:
# ISSSTE    647734
# 1         336554
# Name: ORIGEN, dtype: int64

# %%
df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 0          31/07/2020      15f43a  ISSSTE       4           2   Mujer
# 1          31/07/2020      0d6511  ISSSTE       4          11  Hombre
# 2          31/07/2020      0baff6  ISSSTE       9           9   Mujer
# 3          31/07/2020      1b5b75  ISSSTE       9           9   Mujer
# 4          31/07/2020      120290  ISSSTE       9          15   Mujer
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES TIPO_PACIENTE  ...  \
# 0  No especificado            2              4   Ambulatorio  ...
# 1  No especificado           11             20   Ambulatorio  ...
# 2  No especificado            9             16   Ambulatorio  ...
# 3  No especificado           15             37   Ambulatorio  ...
# 4  No especificado           15             37   Ambulatorio  ...
#
#   CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 0             No       No            No         No  No especificado
# 1             No       No            No         No  No especificado
# 2             No       No            No         No               Si
# 3             Si       No            No         No               No
# 4             No       No            No         No               No
#
#    RESULTADO  MIGRANTE           PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 0   Positivo        99                 El Salvador          99  No aplica
# 1   Positivo        99  Estados Unidos de AmÃ©rica          99  No aplica
# 2   Positivo        99                      Brasil          99  No aplica
# 3   Positivo        99                     EspaÃ±a          99  No aplica
# 4   Positivo         2                   Argentina          99  No aplica
#
# [5 rows x 35 columns]

# %%
# Probar este ejemplo

# mapping_dict = {4: "CRUZ ROJA", 9:"SEDENA"}
# covid2['SECTOR'] = covid2['SECTOR'].map(mapping_dict)

# %% [markdown]
# ## 1.8 Group by dataframe  <a id='id9'> </a>
#
# - Una operación groupby implica alguna combinación de dividir el objeto en función de los valores de una columna o más, aplicar una función y combinar los resultados.
# - Esto se puede usar para agrupar grandes cantidades de datos y calcular operaciones en estos grupos.
# - **Groupby** esencialmente **divide los datos en diferentes grupos dependiendo de la(s) variable(s) de su elección**.
#
# "agrupar por" implica uno o más de los siguientes pasos:
#
# - Dividir los datos en grupos según algunos criterios.
# - Aplicar una función a cada grupo de forma independiente.
# - Combinar los resultados en una estructura de datos.
#
# ![](GroupBy.png)

# %%
#  df = pd.read_csv("20-07-31-COVID19MEXICO-codificado.csv")
df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 0          31/07/2020      15f43a  ISSSTE       4           2   Mujer
# 1          31/07/2020      0d6511  ISSSTE       4          11  Hombre
# 2          31/07/2020      0baff6  ISSSTE       9           9   Mujer
# 3          31/07/2020      1b5b75  ISSSTE       9           9   Mujer
# 4          31/07/2020      120290  ISSSTE       9          15   Mujer
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES TIPO_PACIENTE  ...  \
# 0  No especificado            2              4   Ambulatorio  ...
# 1  No especificado           11             20   Ambulatorio  ...
# 2  No especificado            9             16   Ambulatorio  ...
# 3  No especificado           15             37   Ambulatorio  ...
# 4  No especificado           15             37   Ambulatorio  ...
#
#   CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 0             No       No            No         No  No especificado
# 1             No       No            No         No  No especificado
# 2             No       No            No         No               Si
# 3             Si       No            No         No               No
# 4             No       No            No         No               No
#
#    RESULTADO  MIGRANTE           PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 0   Positivo        99                 El Salvador          99  No aplica
# 1   Positivo        99  Estados Unidos de AmÃ©rica          99  No aplica
# 2   Positivo        99                      Brasil          99  No aplica
# 3   Positivo        99                     EspaÃ±a          99  No aplica
# 4   Positivo         2                   Argentina          99  No aplica
#
# [5 rows x 35 columns]

# %%
df['ENTIDAD_NAC'].value_counts().sort_values()
# Out:
# Colima                   3120
# No especificado          4878
# Queretaro                5528
# Quintana Roo             6448
# Baja California Sur      7072
# Nayarit                  7206
# Campeche                 7441
# Morelos                  8248
# Zacatecas                8991
# Aguascalientes          10872
# Chihuahua               11562
# Chiapas                 12611
# Tlaxcala                13004
# Hidalgo                 13560
# Baja California         14281
# Durango                 14551
# Yucatan                 20486
# Oaxaca                  23198
# Guerrero                25001
# San Luis Potosí         26609
# Sonora                  27003
# Sinaloa                 27701
# Michoacan               31085
# Coahuila                35351
# Tamaulipas              37945
# Jalisco                 39303
# Tabasco                 39673
# Nuevo León              41314
# Puebla                  43654
# Veracruz                46019
# Guanajuato              50623
# México                 112236
# Ciudad de México       207714
# Name: ENTIDAD_NAC, dtype: int64

# %%
df['ENTIDAD_NAC'].value_counts().sort_index()
# Out:
# Aguascalientes          10872
# Baja California         14281
# Baja California Sur      7072
# Campeche                 7441
# Chiapas                 12611
# Chihuahua               11562
# Ciudad de México       207714
# Coahuila                35351
# Colima                   3120
# Durango                 14551
# Guanajuato              50623
# Guerrero                25001
# Hidalgo                 13560
# Jalisco                 39303
# Michoacan               31085
# Morelos                  8248
# México                 112236
# Nayarit                  7206
# No especificado          4878
# Nuevo León              41314
# Oaxaca                  23198
# Puebla                  43654
# Queretaro                5528
# Quintana Roo             6448
# San Luis Potosí         26609
# Sinaloa                 27701
# Sonora                  27003
# Tabasco                 39673
# Tamaulipas              37945
# Tlaxcala                13004
# Veracruz                46019
# Yucatan                 20486
# Zacatecas                8991
# Name: ENTIDAD_NAC, dtype: int64

# %% [markdown]
# ### Ejemplo 1
#
# #### Agrupar por entidad de nacimiento y contar cuantas pruebas se realizaron por entidad

# %%
df.groupby(['ENTIDAD_NAC']).count().head(10)
# Out:
#                      FECHA_ACTUALIZACION  ID_REGISTRO  ORIGEN  SECTOR  \
# ENTIDAD_NAC
# Aguascalientes                     10872        10872   10872   10872
# Baja California                    14281        14281   14281   14281
# Baja California Sur                 7072         7072    7072    7072
# Campeche                            7441         7441    7441    7441
# Chiapas                            12611        12611   12611   12611
# Chihuahua                          11562        11562   11562   11562
# Ciudad de México                  207714       207714  207714  207714
# Coahuila                           35351        35351   35351   35351
# Colima                              3120         3120    3120    3120
# Durango                            14551        14551   14551   14551
#
#                      ENTIDAD_UM    SEXO  ENTIDAD_RES  MUNICIPIO_RES  \
# ENTIDAD_NAC
# Aguascalientes            10872   10872        10872          10872
# Baja California           14281   14281        14281          14281
# Baja California Sur        7072    7072         7072           7072
# Campeche                   7441    7441         7441           7441
# Chiapas                   12611   12611        12611          12611
# Chihuahua                 11562   11562        11562          11562
# Ciudad de México         207714  207714       207714         207714
# Coahuila                  35351   35351        35351          35351
# Colima                     3120    3120         3120           3120
# Durango                   14551   14551        14551          14551
#
#                      TIPO_PACIENTE  FECHA_INGRESO  ...  CARDIOVASCULAR  \
# ENTIDAD_NAC                                        ...
# Aguascalientes               10872          10872  ...           10872
# Baja California              14281          14281  ...           14281
# Baja California Sur           7072           7072  ...            7072
# Campeche                      7441           7441  ...            7441
# Chiapas                      12611          12611  ...           12611
# Chihuahua                    11562          11562  ...           11562
# Ciudad de México            207714         207714  ...          207714
# Coahuila                     35351          35351  ...           35351
# Colima                        3120           3120  ...            3120
# Durango                      14551          14551  ...           14551
#
#                      OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# ENTIDAD_NAC
# Aguascalientes          10872          10872       10872      10872
# Baja California         14281          14281       14281      14281
# Baja California Sur      7072           7072        7072       7072
# Campeche                 7441           7441        7441       7441
# Chiapas                 12611          12611       12611      12611
# Chihuahua               11562          11562       11562      11562
# Ciudad de México       207714         207714      207714     207714
# Coahuila                35351          35351       35351      35351
# Colima                   3120           3120        3120       3120
# Durango                 14551          14551       14551      14551
#
#                      RESULTADO  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  \
# ENTIDAD_NAC
# Aguascalientes           10872     10872              10872        10872
# Baja California          14281     14281              14281        14281
# Baja California Sur       7072      7072               7072         7072
# Campeche                  7441      7441               7441         7441
# Chiapas                  12611     12611              12611        12611
# Chihuahua                11562     11562              11562        11562
# Ciudad de México        207714    207714             207714       207714
# Coahuila                 35351     35351              35351        35351
# Colima                    3120      3120               3120         3120
# Durango                  14551     14551              14551        14551
#
#                         UCI
# ENTIDAD_NAC
# Aguascalientes        10872
# Baja California       14281
# Baja California Sur    7072
# Campeche               7441
# Chiapas               12611
# Chihuahua             11562
# Ciudad de México     207714
# Coahuila              35351
# Colima                 3120
# Durango               14551
#
# [10 rows x 34 columns]

# %%
# Agregamos una nueva columna al dataframe del covid  <<total>> para generar 
# los totales agrupados y hacer el calculo mas rápido al no involucrar todas las columnas

df["Total"] = 0
df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 0          31/07/2020      15f43a  ISSSTE       4           2   Mujer
# 1          31/07/2020      0d6511  ISSSTE       4          11  Hombre
# 2          31/07/2020      0baff6  ISSSTE       9           9   Mujer
# 3          31/07/2020      1b5b75  ISSSTE       9           9   Mujer
# 4          31/07/2020      120290  ISSSTE       9          15   Mujer
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES TIPO_PACIENTE  ... OBESIDAD  \
# 0  No especificado            2              4   Ambulatorio  ...       No
# 1  No especificado           11             20   Ambulatorio  ...       No
# 2  No especificado            9             16   Ambulatorio  ...       No
# 3  No especificado           15             37   Ambulatorio  ...       No
# 4  No especificado           15             37   Ambulatorio  ...       No
#
#   RENAL_CRONICA TABAQUISMO        OTRO_CASO RESULTADO  MIGRANTE  \
# 0            No         No  No especificado  Positivo        99
# 1            No         No  No especificado  Positivo        99
# 2            No         No               Si  Positivo        99
# 3            No         No               No  Positivo        99
# 4            No         No               No  Positivo         2
#
#             PAIS_NACIONALIDAD PAIS_ORIGEN        UCI Total
# 0                 El Salvador          99  No aplica     0
# 1  Estados Unidos de AmÃ©rica          99  No aplica     0
# 2                      Brasil          99  No aplica     0
# 3                     EspaÃ±a          99  No aplica     0
# 4                   Argentina          99  No aplica     0
#
# [5 rows x 36 columns]

# %%
# generamos un nuevo dataframe con 2 columnas para Simplificar el cálculo 
# Notese la velocidad, al incluir solo 2 columnas genera más rápido el resultado

totalcasos = df[["ENTIDAD_NAC","Total"]]  
totalcasos.groupby(['ENTIDAD_NAC']).count().head(10)
# Out:
#                       Total
# ENTIDAD_NAC
# Aguascalientes        10872
# Baja California       14281
# Baja California Sur    7072
# Campeche               7441
# Chiapas               12611
# Chihuahua             11562
# Ciudad de México     207714
# Coahuila              35351
# Colima                 3120
# Durango               14551

# %%
# Se puede incluir la función reset_index() para restablecer un nuevo índice
# al dataframe agrupado, y lo convierte en una estructura de datos más adecuada

totalcasos = df[["ENTIDAD_NAC","Total"]]  
totalcasos.groupby(['ENTIDAD_NAC']).count().reset_index().head()
# Out:
#            ENTIDAD_NAC  Total
# 0       Aguascalientes  10872
# 1      Baja California  14281
# 2  Baja California Sur   7072
# 3             Campeche   7441
# 4              Chiapas  12611

# %% [markdown]
# ### Ejemplo 2
#
# #### Contar cuantas pruebas de COVID se realizaron por estado, desglosado por sexo

# %%
totalcasos = df[["ENTIDAD_NAC","SEXO","Total"]]  
totalcasos.groupby(['ENTIDAD_NAC',"SEXO"]).count().head(10)
# Out:
#                             Total
# ENTIDAD_NAC         SEXO
# Aguascalientes      Hombre   4972
#                     Mujer    5900
# Baja California     Hombre   6889
#                     Mujer    7392
# Baja California Sur Hombre   3272
#                     Mujer    3800
# Campeche            Hombre   4130
#                     Mujer    3311
# Chiapas             Hombre   6993
#                     Mujer    5618

# %%
# De la misma forma podemos resetear el indice para generar un dataframe más amigable

totalcasos = df[["ENTIDAD_NAC","SEXO","Total"]]  
totalcasos.groupby(['ENTIDAD_NAC',"SEXO"]).count().reset_index().head(10)
# Out:
#            ENTIDAD_NAC    SEXO  Total
# 0       Aguascalientes  Hombre   4972
# 1       Aguascalientes   Mujer   5900
# 2      Baja California  Hombre   6889
# 3      Baja California   Mujer   7392
# 4  Baja California Sur  Hombre   3272
# 5  Baja California Sur   Mujer   3800
# 6             Campeche  Hombre   4130
# 7             Campeche   Mujer   3311
# 8              Chiapas  Hombre   6993
# 9              Chiapas   Mujer   5618

# %% [markdown]
# ### Ejemplo 3
#
# #### Contar cuantas pruebas de COVID se realizaron por estado, desglosado por sexo y tipo  de paciente

# %%
totalcasos = df[["ENTIDAD_NAC", "SEXO", "TIPO_PACIENTE", "Total"]]  
totalcasos.groupby(['ENTIDAD_NAC',"SEXO", "TIPO_PACIENTE"]).count().head(10)
# Out:
#                                           Total
# ENTIDAD_NAC         SEXO   TIPO_PACIENTE
# Aguascalientes      Hombre Ambulatorio     4139
#                            Hospitalizado    833
#                     Mujer  Ambulatorio     5261
#                            Hospitalizado    639
# Baja California     Hombre Ambulatorio     4761
#                            Hospitalizado   2128
#                     Mujer  Ambulatorio     5942
#                            Hospitalizado   1450
# Baja California Sur Hombre Ambulatorio     2849
#                            Hospitalizado    423

# %%
# De la misma forma, reseteamos el indice

# Agregamos un nivel más de grupos

totalcasos = df[["ENTIDAD_NAC", "SEXO", "TIPO_PACIENTE", "Total"]]  

totalcasos.groupby(['ENTIDAD_NAC',"SEXO", "TIPO_PACIENTE"]).count().reset_index().head(10)
# Out:
#            ENTIDAD_NAC    SEXO  TIPO_PACIENTE  Total
# 0       Aguascalientes  Hombre    Ambulatorio   4139
# 1       Aguascalientes  Hombre  Hospitalizado    833
# 2       Aguascalientes   Mujer    Ambulatorio   5261
# 3       Aguascalientes   Mujer  Hospitalizado    639
# 4      Baja California  Hombre    Ambulatorio   4761
# 5      Baja California  Hombre  Hospitalizado   2128
# 6      Baja California   Mujer    Ambulatorio   5942
# 7      Baja California   Mujer  Hospitalizado   1450
# 8  Baja California Sur  Hombre    Ambulatorio   2849
# 9  Baja California Sur  Hombre  Hospitalizado    423

# %% [markdown]
# ###  Ejemplo 4
#
# #### Contar el numero de casos por día

# %%
totalcasos = df[ ["FECHA_INGRESO", "Total"] ]
totalcasos.head()
# Out:
#   FECHA_INGRESO  Total
# 0    18/04/2020      0
# 1    18/06/2020      0
# 2    15/03/2020      0
# 3    20/03/2020      0
# 4    02/05/2020      0

# %%
# El resultado que arroja es correcto el calculo, pero lo que esta mal es que 
# el tipo de dato es como texto y por eso no hay un orden cronológico
#  tenemos que convertir a tipo de dato **datetime**

totalcasos.groupby(["FECHA_INGRESO"]).count().reset_index().head(10)
# Out:
#   FECHA_INGRESO  Total
# 0    01/01/2020      5
# 1    01/02/2020      8
# 2    01/03/2020     29
# 3    01/04/2020   1593
# 4    01/05/2020   3074
# 5    01/06/2020  10771
# 6    01/07/2020  15219
# 7    02/01/2020     16
# 8    02/02/2020     12
# 9    02/03/2020     78

# %%
# Notese que la columna FECHA_INGRESO es de tipo object 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984288 entries, 0 to 984287
# Data columns (total 36 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  984288 non-null  object
#  1   ID_REGISTRO          984288 non-null  object
#  2   ORIGEN               984288 non-null  object
#  3   SECTOR               984288 non-null  int64
#  4   ENTIDAD_UM           984288 non-null  int64
#  5   SEXO                 984288 non-null  object
#  6   ENTIDAD_NAC          984288 non-null  object
#  7   ENTIDAD_RES          984288 non-null  int64
#  8   MUNICIPIO_RES        984288 non-null  int64
#  9   TIPO_PACIENTE        984288 non-null  object
#  10  FECHA_INGRESO        984288 non-null  object
#  11  FECHA_SINTOMAS       984288 non-null  object
#  12  FECHA_DEF            984288 non-null  object
#  13  INTUBADO             984288 non-null  object
#  14  NEUMONIA             984288 non-null  object
#  15  EDAD                 984288 non-null  int64
#  16  NACIONALIDAD         984288 non-null  int64
#  17  EMBARAZO             984288 non-null  object
#  18  HABLA_LENGUA_INDIG   984288 non-null  object
#  19  DIABETES             984288 non-null  object
#  20  EPOC                 984288 non-null  object
#  21  ASMA                 984288 non-null  object
#  22  INMUSUPR             984288 non-null  object
#  23  HIPERTENSION         984288 non-null  object
#  24  OTRA_COM             984288 non-null  object
#  25  CARDIOVASCULAR       984288 non-null  object
#  26  OBESIDAD             984288 non-null  object
#  27  RENAL_CRONICA        984288 non-null  object
#  28  TABAQUISMO           984288 non-null  object
#  29  OTRO_CASO            984288 non-null  object
#  30  RESULTADO            984288 non-null  object
#  31  MIGRANTE             984288 non-null  int64
#  32  PAIS_NACIONALIDAD    984288 non-null  object
#  33  PAIS_ORIGEN          984288 non-null  object
#  34  UCI                  984288 non-null  object
#  35  Total                984288 non-null  int64
# dtypes: int64(8), object(28)
# memory usage: 270.3+ MB

# %%
# Convertimos a datetime la columna FECHA_INGRESO

df['FECHA_INGRESO'] = pd.to_datetime(df['FECHA_INGRESO'], format="%d/%m/%Y")

# %%
# Volvemos a verificar y ya esta el cambio

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984288 entries, 0 to 984287
# Data columns (total 36 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  984288 non-null  object
#  1   ID_REGISTRO          984288 non-null  object
#  2   ORIGEN               984288 non-null  object
#  3   SECTOR               984288 non-null  int64
#  4   ENTIDAD_UM           984288 non-null  int64
#  5   SEXO                 984288 non-null  object
#  6   ENTIDAD_NAC          984288 non-null  object
#  7   ENTIDAD_RES          984288 non-null  int64
#  8   MUNICIPIO_RES        984288 non-null  int64
#  9   TIPO_PACIENTE        984288 non-null  object
#  10  FECHA_INGRESO        984288 non-null  datetime64[ns]
#  11  FECHA_SINTOMAS       984288 non-null  object
#  12  FECHA_DEF            984288 non-null  object
#  13  INTUBADO             984288 non-null  object
#  14  NEUMONIA             984288 non-null  object
#  15  EDAD                 984288 non-null  int64
#  16  NACIONALIDAD         984288 non-null  int64
#  17  EMBARAZO             984288 non-null  object
#  18  HABLA_LENGUA_INDIG   984288 non-null  object
#  19  DIABETES             984288 non-null  object
#  20  EPOC                 984288 non-null  object
#  21  ASMA                 984288 non-null  object
#  22  INMUSUPR             984288 non-null  object
#  23  HIPERTENSION         984288 non-null  object
#  24  OTRA_COM             984288 non-null  object
#  25  CARDIOVASCULAR       984288 non-null  object
#  26  OBESIDAD             984288 non-null  object
#  27  RENAL_CRONICA        984288 non-null  object
#  28  TABAQUISMO           984288 non-null  object
#  29  OTRO_CASO            984288 non-null  object
#  30  RESULTADO            984288 non-null  object
#  31  MIGRANTE             984288 non-null  int64
#  32  PAIS_NACIONALIDAD    984288 non-null  object
#  33  PAIS_ORIGEN          984288 non-null  object
#  34  UCI                  984288 non-null  object
#  35  Total                984288 non-null  int64
# dtypes: datetime64[ns](1), int64(8), object(27)
# memory usage: 270.3+ MB

# %%
totalcasos = df[ ["FECHA_INGRESO", "Total"] ]
totalcasos = totalcasos.groupby( ["FECHA_INGRESO"] ).count().reset_index()
totalcasos.head(10)
# Out:
#   FECHA_INGRESO  Total
# 0    2020-01-01      5
# 1    2020-01-02     16
# 2    2020-01-03     18
# 3    2020-01-04      6
# 4    2020-01-05     14
# 5    2020-01-06     28
# 6    2020-01-07     28
# 7    2020-01-08     15
# 8    2020-01-09     44
# 9    2020-01-10     39

# %%
totalcasos.tail(10)
# Out:
#     FECHA_INGRESO  Total
# 203    2020-07-22  16150
# 204    2020-07-23  15579
# 205    2020-07-24  15237
# 206    2020-07-25   6881
# 207    2020-07-26   4720
# 208    2020-07-27  14753
# 209    2020-07-28  13205
# 210    2020-07-29  12769
# 211    2020-07-30  11635
# 212    2020-07-31    853

# %%
# Los siguientes 2 celdas donde se grafica
# No hacerla en clase

totalcasos.set_index("FECHA_INGRESO", inplace = True)
totalcasos
# Out:
#                Total
# FECHA_INGRESO
# 2020-01-01         5
# 2020-01-02        16
# 2020-01-03        18
# 2020-01-04         6
# 2020-01-05        14
# ...              ...
# 2020-07-27     14753
# 2020-07-28     13205
# 2020-07-29     12769
# 2020-07-30     11635
# 2020-07-31       853
#
# [213 rows x 1 columns]

# %%
totalcasos.plot.line()
# Out:
# <AxesSubplot:xlabel='FECHA_INGRESO'>

# %% [markdown]
# ### Ejemplo 5
#
# #### Contar los que dieron positivo, y que tienen diabetes e hipertensión

# %%
# Primero especificamos los criterios de seleccion de los registros, luego
# en la proyeccion indicamos las columnas a mostrar y ahi aplicamos la funcion group by

PruebasDgo = df[ ( df['RESULTADO'] == "Positivo") &
                ( df['DIABETES'] == "Si") & 
                ( df['HIPERTENSION'] == "Si")] [["ENTIDAD_NAC","Total"]].groupby("ENTIDAD_NAC").count().reset_index() 
PruebasDgo.head(10)
# Out:
#            ENTIDAD_NAC  Total
# 0       Aguascalientes    315
# 1      Baja California    909
# 2  Baja California Sur    193
# 3             Campeche    383
# 4              Chiapas    731
# 5            Chihuahua    496
# 6     Ciudad de México   5457
# 7             Coahuila    777
# 8               Colima    145
# 9              Durango    398

# %%
PruebasDgo.set_index("ENTIDAD_NAC", inplace = True)

# %%
PruebasDgo.sort_values("Total")
# Out:
#                      Total
# ENTIDAD_NAC
# No especificado         49
# Colima                 145
# Baja California Sur    193
# Quintana Roo           198
# Aguascalientes         315
# Queretaro              325
# Campeche               383
# Durango                398
# Morelos                409
# Nayarit                419
# Tlaxcala               424
# Zacatecas              435
# Chihuahua              496
# Chiapas                731
# Coahuila               777
# Hidalgo                793
# Yucatan                864
# San Luis Potosí        882
# Baja California        909
# Oaxaca                 943
# Nuevo León             995
# Michoacan             1019
# Tamaulipas            1161
# Guerrero              1248
# Jalisco               1530
# Sinaloa               1603
# Puebla                1725
# Sonora                1776
# Tabasco               1875
# Guanajuato            1885
# Veracruz              2771
# México                3189
# Ciudad de México      5457

# %%
PruebasDgo.sort_values("Total").tail(5).plot.barh()
# Out:
# <AxesSubplot:ylabel='ENTIDAD_NAC'>

# %%
PruebasDgo.sort_values("Total").head(5).plot.barh()
# Out:
# <AxesSubplot:ylabel='ENTIDAD_NAC'>

# %%
PruebasDgo.sort_values("Total").plot.barh()
# Out:
# <AxesSubplot:ylabel='ENTIDAD_NAC'>

# %% [markdown]
# ### Ejemplos con el archivo DiagnosticoIMCOcsv

# %%
# El archivo DiagnosticoIMCOcsv estaba con comas con separadores de miles
# debe volverse a descargar

DiagnosticoIMCO = pd.read_csv("DiagnosticoIMCOcsv.csv")

DiagnosticoIMCO.head(10)
# Out:
#              Estado  AportacionesFederales  ParticipacionesFederales  \
# 0    Aguascalientes            10676000000                7158000000
# 1        Guanajuato            30265000000               29097000000
# 2         Queretaro            12321000000               11162000000
# 3   San Luis Potosi            20428000000               13656000000
# 4         Zacatecas            14101000000                7903000000
# 5  Ciudad de México            16205000000               68270000000
# 6  Estado de México            77925000000               97088000000
# 7           Morelos            12967000000                9668000000
# 8          Coahuila            17367000000               15930000000
# 9        Nuevo León            24371000000               31371000000
#
#    RecaudacionImpuestos        Region
# 0            1232000000  Centro-Norte
# 1            4373000000  Centro-Norte
# 2            2852000000  Centro-Norte
# 3            1937000000  Centro-Norte
# 4            1192000000  Centro-Norte
# 5           58800000000    Centro-Sur
# 6           21451000000    Centro-Sur
# 7             632000000    Centro-Sur
# 8            2753000000       Noreste
# 9           10579000000       Noreste

# %%
# Verificar que en el tipo de dato sea int64
DiagnosticoIMCO.dtypes
# Out:
# Estado                      object
# AportacionesFederales        int64
# ParticipacionesFederales     int64
# RecaudacionImpuestos         int64
# Region                      object
# dtype: object

# %%
# Agregamos una columna total para ahi generar el calculo

DiagnosticoIMCO["Total"] = 0
DiagnosticoIMCO.head()
# Out:
#             Estado  AportacionesFederales  ParticipacionesFederales  \
# 0   Aguascalientes            10676000000                7158000000
# 1       Guanajuato            30265000000               29097000000
# 2        Queretaro            12321000000               11162000000
# 3  San Luis Potosi            20428000000               13656000000
# 4        Zacatecas            14101000000                7903000000
#
#    RecaudacionImpuestos        Region  Total
# 0            1232000000  Centro-Norte      0
# 1            4373000000  Centro-Norte      0
# 2            2852000000  Centro-Norte      0
# 3            1937000000  Centro-Norte      0
# 4            1192000000  Centro-Norte      0

# %%
# calculamos la recuadación de impuestos por Region

totalReg = DiagnosticoIMCO[["Region", "RecaudacionImpuestos", "Total"]]  

total2 = totalReg.groupby(['Region'])['RecaudacionImpuestos'].sum().reset_index()

# %%
total2
# Out:
#          Region  RecaudacionImpuestos
# 0  Centro-Norte           11586000000
# 1    Centro-Sur           80883000000
# 2       Noreste           17825000000
# 3      Noroeste           18900000000
# 4         Oeste            5533000000
# 5       Oriente           11553000000
# 6      SurOeste            4198000000
# 7       Sureste            9585000000

# %%
total2["RecaudacionImpuestos"] = total2["RecaudacionImpuestos"].astype(float).apply(lambda x: f'{x:,}')

# %%
total2
# Out:
#          Region RecaudacionImpuestos
# 0  Centro-Norte     11,586,000,000.0
# 1    Centro-Sur     80,883,000,000.0
# 2       Noreste     17,825,000,000.0
# 3      Noroeste     18,900,000,000.0
# 4         Oeste      5,533,000,000.0
# 5       Oriente     11,553,000,000.0
# 6      SurOeste      4,198,000,000.0
# 7       Sureste      9,585,000,000.0

# %%
total2.dtypes
# Out:
# Region                  object
# RecaudacionImpuestos    object
# dtype: object

# %% [markdown]
# ###  5.9.1 Ejercicios de Group By      <a id='id91'> </a>
#
# 1. Calcular cuantas pruebas se realizaron por edad
# 2. Mostrar por Sexo los resultados obtenidos por la prueba COVID
# 3. Mostrar el detalle de la situacion de la DIABETES de las personas que dieron positivo desglosado por sexo
# 4. Mostrar el detalle de la situacion de TIPO_PACIENTE de las personas que dieron positivo desglosado por sexo
# 5. Generar un reporte que muestre el número de defunciones desglozado por estado y sexo

# %% [markdown]
# ### Ejercicio 1
#
# - Calcular cuantas pruebas se realizaron por edad

# %%
PruebasDgo = df[["EDAD","Total"]].groupby("EDAD").count().reset_index() 
PruebasDgo.head()
# Out:
#    EDAD  Total
# 0     0   4128
# 1     1   3119
# 2     2   1913
# 3     3   1650
# 4     4   1688

# %% [markdown]
# ###  Segmentacion de datos por  edades
#
# - Se usa la funcion **cut** de pandas
# - Usar **cut** cuando se desea segmentar y ordenar valores de datos en contenedores.
# - Esta función también es útil para **pasar de una variable continua a una variable categórica**.
# - Por ejemplo, cortar podría **convertir edades en grupos de rangos de edad**.
# - Admite el agrupamiento en un número igual de contenedores o en una matriz de contenedores especificada previamente.

# %%
bins = [-1, 9, 19, 29, 39, 49, 59, 69, 79, 89, 99, 130]

# %%
names = ["0-9", "10-19", "20-29", "30-39", "40-49", "50-59", "60-9", "70-79", "80-89", "90-99", "+100"]

# %%
PruebasDgo["EDAD"] = pd.cut(PruebasDgo["EDAD"], bins, labels = names)

# %%
PruebasDgo.head(12)
# Out:
#      EDAD  Total
# 0     0-9   4128
# 1     0-9   3119
# 2     0-9   1913
# 3     0-9   1650
# 4     0-9   1688
# 5     0-9   1585
# 6     0-9   1690
# 7     0-9   1637
# 8     0-9   1743
# 9     0-9   1746
# 10  10-19   1923
# 11  10-19   1973

# %%
PruebasDgo = PruebasDgo[["EDAD","Total"]].groupby("EDAD").sum().reset_index()

# %%
PruebasDgo
# Out:
#      EDAD   Total
# 0     0-9   20899
# 1   10-19   32503
# 2   20-29  167416
# 3   30-39  236966
# 4   40-49  213758
# 5   50-59  158386
# 6    60-9   88407
# 7   70-79   44500
# 8   80-89   18103
# 9   90-99    3159
# 10   +100     191

# %%
PruebasDgo.set_index("EDAD", inplace = True)

# %%
PruebasDgo.plot.barh()
# Out:
# <AxesSubplot:ylabel='EDAD'>

# %% [markdown]
# ### Ejercicio 2
#
# - Mostrar por Sexo los resultados obtenidos por la prueba COVID

# %%
totalcasos = df[["SEXO", "RESULTADO", "Total"]]
totalcasos.head()
# Out:
#      SEXO RESULTADO  Total
# 0   Mujer  Positivo      0
# 1  Hombre  Positivo      0
# 2   Mujer  Positivo      0
# 3   Mujer  Positivo      0
# 4   Mujer  Positivo      0

# %%
totalcasos = totalcasos.groupby(["SEXO", "RESULTADO"]).count()

# %%
totalcasos
# Out:
#                    Total
# SEXO   RESULTADO
# Hombre Negativo   219683
#        Pendiente   45501
#        Positivo   226007
# Mujer  Negativo   249946
#        Pendiente   44521
#        Positivo   198630

# %% [markdown]
# ### Ejercicio 3
#
# - Mostrar el detalle de la situacion de la DIABETES de las personas que dieron positivo desglosado por sexo

# %%
totalcasos = df[(df['RESULTADO'] == "Positivo")] [["SEXO", "DIABETES", "Total"]]
totalcasos.head()
# Out:
#      SEXO DIABETES  Total
# 0   Mujer       No      0
# 1  Hombre       No      0
# 2   Mujer       No      0
# 3   Mujer       No      0
# 4   Mujer       No      0

# %%
totalcasos = totalcasos.groupby( ["SEXO", "DIABETES"] ).count()

# %%
totalcasos
# Out:
#                    Total
# SEXO   DIABETES
# Hombre No         188653
#        Se ignora     855
#        Si          36499
# Mujer  No         166767
#        Se ignora     555
#        Si          31308

# %% [markdown]
# ### Ejercicio 4
#
# - Mostrar el detalle de la situacion de TIPO_PACIENTE de las personas que dieron positivo desglosado por sexo

# %%
totalcasos = df[(df['RESULTADO'] == "Positivo")] [["SEXO", "TIPO_PACIENTE", "Total"]]
totalcasos.head()
# Out:
#      SEXO TIPO_PACIENTE  Total
# 0   Mujer   Ambulatorio      0
# 1  Hombre   Ambulatorio      0
# 2   Mujer   Ambulatorio      0
# 3   Mujer   Ambulatorio      0
# 4   Mujer   Ambulatorio      0

# %%
totalcasos = totalcasos.groupby(["SEXO","TIPO_PACIENTE"]).count()
totalcasos
# Out:
#                        Total
# SEXO   TIPO_PACIENTE
# Hombre Ambulatorio    155160
#        Hospitalizado   70847
# Mujer  Ambulatorio    154127
#        Hospitalizado   44503

# %% [markdown]
# ### Ejercicio 5
#
# - Generar un reporte que muestre el número de defunciones desglozado por estado y sexo

# %%
# Mostramos la fecha de defuncion del nuevo dataframe para verificar las fechas

totalcasos = df[ df["FECHA_DEF"] !="9999-99-99"] [["ENTIDAD_NAC", "SEXO", "FECHA_DEF","Total"]]
totalcasos
# Out:
#             ENTIDAD_NAC    SEXO   FECHA_DEF  Total
# 13      No especificado  Hombre  11/05/2020      0
# 178     No especificado   Mujer  26/03/2020      0
# 196     No especificado  Hombre  01/05/2020      0
# 199     No especificado  Hombre  06/06/2020      0
# 364     No especificado  Hombre  07/05/2020      0
# ...                 ...     ...         ...    ...
# 984204        Zacatecas  Hombre  25/07/2020      0
# 984225        Zacatecas   Mujer  29/07/2020      0
# 984228        Zacatecas  Hombre  28/07/2020      0
# 984239        Zacatecas   Mujer  29/07/2020      0
# 984258        Zacatecas  Hombre  15/07/2020      0
#
# [60247 rows x 4 columns]

# %%
# Quitamos la fecha de defuncion del nuevo dataframe porque no es necesario para el calculo

totalcasos = df[ df["FECHA_DEF"] !="9999-99-99"] [["ENTIDAD_NAC", "SEXO", "Total"]]
totalcasos
# Out:
#             ENTIDAD_NAC    SEXO  Total
# 13      No especificado  Hombre      0
# 178     No especificado   Mujer      0
# 196     No especificado  Hombre      0
# 199     No especificado  Hombre      0
# 364     No especificado  Hombre      0
# ...                 ...     ...    ...
# 984204        Zacatecas  Hombre      0
# 984225        Zacatecas   Mujer      0
# 984228        Zacatecas  Hombre      0
# 984239        Zacatecas   Mujer      0
# 984258        Zacatecas  Hombre      0
#
# [60247 rows x 3 columns]

# %%
totalcasos = totalcasos.groupby(["ENTIDAD_NAC", "SEXO"]).count()
totalcasos
# Out:
#                             Total
# ENTIDAD_NAC         SEXO
# Aguascalientes      Hombre    199
#                     Mujer     150
# Baja California     Hombre    920
#                     Mujer     607
# Baja California Sur Hombre    100
# ...                           ...
# Veracruz            Mujer    1484
# Yucatan             Hombre    959
#                     Mujer     539
# Zacatecas           Hombre    411
#                     Mujer     249
#
# [66 rows x 1 columns]

# %% [markdown]
# ### Ejercicio 6
#
# - Calcular cuantas

# %% [markdown]
# ## 5.9.2  Aggregación <a id='id92'> </a>
#
# - Una vez que se ha creado el objeto **GroupBy**, hay varios métodos disponibles para realizar un cálculo en los datos agrupados.
# - La API de agregación permite expresar múltiples operaciones de agregación de una manera concisa. El punto de entrada para la agregación es **DataFrame.aggregate() o el alias DataFrame.agg()**.
#
# #### Agregar con múltiples funciones
#
# - Puede pasar **múltiples argumentos de agregación como una lista**.
# - Los resultados de cada una de las funciones pasadas serán una fila en el DataFrame resultante.
# - Estos se nombran naturalmente a partir de la función de agregación.
#
# En muchas situaciones es posible que deseemos dividir el conjunto de datos en grupos y hacer algo con esos grupos. Es posible que deseemos realizar una de las siguientes acciones:
#
# - Calcular una estadística de resumen (o estadísticas) para cada grupo.
# - Calcular sumas o medias de grupos.
# - Calcular los tamaños/conteos de los grupos.
#
# Fuente:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html?highlight=filter#aggregation

# %%
DiagnosticoIMCO.head(7)
# Out:
#              Estado  AportacionesFederales  ParticipacionesFederales  \
# 0    Aguascalientes            10676000000                7158000000
# 1        Guanajuato            30265000000               29097000000
# 2         Queretaro            12321000000               11162000000
# 3   San Luis Potosi            20428000000               13656000000
# 4         Zacatecas            14101000000                7903000000
# 5  Ciudad de México            16205000000               68270000000
# 6  Estado de México            77925000000               97088000000
#
#    RecaudacionImpuestos        Region  Total
# 0            1232000000  Centro-Norte      0
# 1            4373000000  Centro-Norte      0
# 2            2852000000  Centro-Norte      0
# 3            1937000000  Centro-Norte      0
# 4            1192000000  Centro-Norte      0
# 5           58800000000    Centro-Sur      0
# 6           21451000000    Centro-Sur      0

# %%
DiagnosticoIMCO.groupby("Region").aggregate(np.sum)
# Out:
#               AportacionesFederales  ParticipacionesFederales  \
# Region
# Centro-Norte            87791000000               68976000000
# Centro-Sur             107097000000              175026000000
# Noreste                 66193000000               66294000000
# Noroeste                99905000000               85280000000
# Oeste                   86379000000               77079000000
# Oriente                130153000000               92195000000
# SurOeste               128982000000               63468000000
# Sureste                 48518000000               43447000000
#
#               RecaudacionImpuestos  Total
# Region
# Centro-Norte           11586000000      0
# Centro-Sur             80883000000      0
# Noreste                17825000000      0
# Noroeste               18900000000      0
# Oeste                   5533000000      0
# Oriente                11553000000      0
# SurOeste                4198000000      0
# Sureste                 9585000000      0

# %%
# Por el warning que marca este código, lo ideal seria proyectar las columnas que si se pueden sacar la estadistica

DiagnosticoIMCO.groupby("Region").aggregate( [np.size, np.sum, np.mean] )
# Out:
# C:\Users\jgab\AppData\Local\Temp\ipykernel_8388\291792132.py:3: FutureWarning: ['Estado'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   DiagnosticoIMCO.groupby("Region").aggregate( [np.size, np.sum, np.mean] )
#              AportacionesFederales                              \
#                               size           sum          mean
# Region
# Centro-Norte                     5   87791000000  1.755820e+10
# Centro-Sur                       3  107097000000  3.569900e+10
# Noreste                          3   66193000000  2.206433e+10
# Noroeste                         6   99905000000  1.665083e+10
# Oeste                            4   86379000000  2.159475e+10
# Oriente                          4  130153000000  3.253825e+10
# SurOeste                         3  128982000000  4.299400e+10
# Sureste                          4   48518000000  1.212950e+10
#
#              ParticipacionesFederales                              \
#                                  size           sum          mean
# Region
# Centro-Norte                        5   68976000000  1.379520e+10
# Centro-Sur                          3  175026000000  5.834200e+10
# Noreste                             3   66294000000  2.209800e+10
# Noroeste                            6   85280000000  1.421333e+10
# Oeste                               4   77079000000  1.926975e+10
# Oriente                             4   92195000000  2.304875e+10
# SurOeste                            3   63468000000  2.115600e+10
# Sureste                             4   43447000000  1.086175e+10
#
#              RecaudacionImpuestos                            Total
#                              size          sum          mean  size sum mean
# Region
# Centro-Norte                    5  11586000000  2.317200e+09     5   0  0.0
# Centro-Sur                      3  80883000000  2.696100e+10     3   0  0.0
# Noreste                         3  17825000000  5.941667e+09     3   0  0.0
# Noroeste                        6  18900000000  3.150000e+09     6   0  0.0
# Oeste                           4   5533000000  1.383250e+09     4   0  0.0
# Oriente                         4  11553000000  2.888250e+09     4   0  0.0
# SurOeste                        3   4198000000  1.399333e+09     3   0  0.0
# Sureste                         4   9585000000  2.396250e+09     4   0  0.0

# %%
DiagnosticoIMCO.groupby("Region").agg(
    Estados = pd.NamedAgg(column="RecaudacionImpuestos", aggfunc="size"),
    Minimo = pd.NamedAgg(column="RecaudacionImpuestos", aggfunc="min"),
    Maximo = pd.NamedAgg(column="RecaudacionImpuestos", aggfunc="max"),
    Total = pd.NamedAgg(column="RecaudacionImpuestos", aggfunc="sum"),
    Promedio = pd.NamedAgg(column="RecaudacionImpuestos", aggfunc="mean")
)
# Out:
#               Estados      Minimo       Maximo        Total      Promedio
# Region
# Centro-Norte        5  1192000000   4373000000  11586000000  2.317200e+09
# Centro-Sur          3   632000000  58800000000  80883000000  2.696100e+10
# Noreste             3  2753000000  10579000000  17825000000  5.941667e+09
# Noroeste            6  1112000000   5597000000  18900000000  3.150000e+09
# Oeste               4   822000000   1935000000   5533000000  1.383250e+09
# Oriente             4   552000000   4872000000  11553000000  2.888250e+09
# SurOeste            3  1249000000   1478000000   4198000000  1.399333e+09
# Sureste             4  1663000000   3930000000   9585000000  2.396250e+09

# %%
DiagnosticoIMCO.head(7).style.set_caption('Ingresos de los estados')
# Out:
# <style type="text/css">
# </style>
# <table id="T_75221">
#   <caption>Ingresos de los estados</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75221_level0_col0" class="col_heading level0 col0" >Estado</th>
#       <th id="T_75221_level0_col1" class="col_heading level0 col1" >AportacionesFederales</th>
#       <th id="T_75221_level0_col2" class="col_heading level0 col2" >ParticipacionesFederales</th>
#       <th id="T_75221_level0_col3" class="col_heading level0 col3" >RecaudacionImpuestos</th>
#       <th id="T_75221_level0_col4" class="col_heading level0 col4" >Region</th>
#       <th id="T_75221_level0_col5" class="col_heading level0 col5" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75221_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75221_row0_col0" class="data row0 col0" >Aguascalientes</td>
#       <td id="T_75221_row0_col1" class="data row0 col1" >10676000000</td>
#       <td id="T_75221_row0_col2" class="data row0 col2" >7158000000</td>
#       <td id="T_75221_row0_col3" class="data row0 col3" >1232000000</td>
#       <td id="T_75221_row0_col4" class="data row0 col4" >Centro-Norte</td>
#       <td id="T_75221_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75221_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75221_row1_col0" class="data row1 col0" >Guanajuato</td>
#       <td id="T_75221_row1_col1" class="data row1 col1" >30265000000</td>
#       <td id="T_75221_row1_col2" class="data row1 col2" >29097000000</td>
#       <td id="T_75221_row1_col3" class="data row1 col3" >4373000000</td>
#       <td id="T_75221_row1_col4" class="data row1 col4" >Centro-Norte</td>
#       <td id="T_75221_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75221_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75221_row2_col0" class="data row2 col0" >Queretaro</td>
#       <td id="T_75221_row2_col1" class="data row2 col1" >12321000000</td>
#       <td id="T_75221_row2_col2" class="data row2 col2" >11162000000</td>
#       <td id="T_75221_row2_col3" class="data row2 col3" >2852000000</td>
#       <td id="T_75221_row2_col4" class="data row2 col4" >Centro-Norte</td>
#       <td id="T_75221_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75221_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_75221_row3_col0" class="data row3 col0" >San Luis Potosi</td>
#       <td id="T_75221_row3_col1" class="data row3 col1" >20428000000</td>
#       <td id="T_75221_row3_col2" class="data row3 col2" >13656000000</td>
#       <td id="T_75221_row3_col3" class="data row3 col3" >1937000000</td>
#       <td id="T_75221_row3_col4" class="data row3 col4" >Centro-Norte</td>
#       <td id="T_75221_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75221_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_75221_row4_col0" class="data row4 col0" >Zacatecas</td>
#       <td id="T_75221_row4_col1" class="data row4 col1" >14101000000</td>
#       <td id="T_75221_row4_col2" class="data row4 col2" >7903000000</td>
#       <td id="T_75221_row4_col3" class="data row4 col3" >1192000000</td>
#       <td id="T_75221_row4_col4" class="data row4 col4" >Centro-Norte</td>
#       <td id="T_75221_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75221_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_75221_row5_col0" class="data row5 col0" >Ciudad de México</td>
#       <td id="T_75221_row5_col1" class="data row5 col1" >16205000000</td>
#       <td id="T_75221_row5_col2" class="data row5 col2" >68270000000</td>
#       <td id="T_75221_row5_col3" class="data row5 col3" >58800000000</td>
#       <td id="T_75221_row5_col4" class="data row5 col4" >Centro-Sur</td>
#       <td id="T_75221_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75221_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_75221_row6_col0" class="data row6 col0" >Estado de México</td>
#       <td id="T_75221_row6_col1" class="data row6 col1" >77925000000</td>
#       <td id="T_75221_row6_col2" class="data row6 col2" >97088000000</td>
#       <td id="T_75221_row6_col3" class="data row6 col3" >21451000000</td>
#       <td id="T_75221_row6_col4" class="data row6 col4" >Centro-Sur</td>
#       <td id="T_75221_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Para el siguiente ejercicio vamos a Mostrar la edad minima, maxima y promedio por # de los que fallecieron
# Primero verificamos la informacion en general 

totalcasos = df[ df["FECHA_DEF"] !="9999-99-99"] [["ENTIDAD_NAC", "EDAD","Total"]]
totalcasos
# Out:
#             ENTIDAD_NAC  EDAD  Total
# 13      No especificado    74      0
# 178     No especificado    57      0
# 196     No especificado    60      0
# 199     No especificado    50      0
# 364     No especificado    35      0
# ...                 ...   ...    ...
# 984204        Zacatecas    89      0
# 984225        Zacatecas    78      0
# 984228        Zacatecas    74      0
# 984239        Zacatecas    60      0
# 984258        Zacatecas    70      0
#
# [60247 rows x 3 columns]

# %%
# Ahora si Mostramos la edad minima, maxima y promedio por ESTADO de los que fallecieron

totalcasos = df[ df["FECHA_DEF"] !="9999-99-99"] [["ENTIDAD_NAC", "EDAD"]]
totalcasos.groupby(["ENTIDAD_NAC"]).agg(['min', 'max', 'mean']).head(15)
# Out:
#                     EDAD
#                      min  max       mean
# ENTIDAD_NAC
# Aguascalientes         0  100  60.790831
# Baja California        0  102  58.260642
# Baja California Sur    1   96  62.068182
# Campeche               0   99  62.072897
# Chiapas                0   94  61.575281
# Chihuahua              0  101  60.602388
# Ciudad de México       0  100  59.831533
# Coahuila               0   99  61.739666
# Colima                 0   95  63.975369
# Durango                0   98  63.960983
# Guanajuato             0   99  64.507042
# Guerrero               0   99  63.404538
# Hidalgo                0   96  61.795845
# Jalisco                0  100  63.094970
# Michoacan              0  101  64.515577

# %%
# Agregamos el SEXO

totalcasos = df[ df["FECHA_DEF"] !="9999-99-99"] [["ENTIDAD_NAC", "SEXO", "EDAD"]]
totalcasos.groupby(["ENTIDAD_NAC", "SEXO"]).agg(['min', 'max', 'mean']).head(15)
# Out:
#                            EDAD
#                             min  max       mean
# ENTIDAD_NAC         SEXO
# Aguascalientes      Hombre    0  100  59.351759
#                     Mujer     0   95  62.700000
# Baja California     Hombre    0   98  57.452174
#                     Mujer     0  102  59.485997
# Baja California Sur Hombre    3   96  59.040000
#                     Mujer     1   92  66.052632
# Campeche            Hombre    0   99  62.420588
#                     Mujer     0   99  61.466667
# Chiapas             Hombre    0   94  61.898901
#                     Mujer     0   94  60.882353
# Chihuahua           Hombre    0  100  59.088785
#                     Mujer     0  101  62.776286
# Ciudad de México    Hombre    0  100  59.018879
#                     Mujer     0   99  61.594438
# Coahuila            Hombre    0   93  61.570988

# %% [markdown]
# # ESTE TEMA ESTA PENDIENTE......  NO HA SALIDO BIEN
#
# ## 5.9.2  Filtros en grupos <a id='id92'> </a>
#
# Descartar algunos grupos, de acuerdo con un cálculo por grupos que evalúa Verdadero o Falso. Algunos ejemplos:
#
# - Descartar los datos que pertenecen a grupos con solo unos pocos miembros.
# - Filtrar los datos según la suma o la media del grupo.
#
# Fuente:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html?highlight=filter#dataframe-column-selection-in-groupby

# %%
totalcasos = df[ df["FECHA_DEF"] !="9999-99-99"] [["ENTIDAD_NAC", "SEXO", "Total"]]
totalcasos = totalcasos.groupby(["ENTIDAD_NAC", "SEXO"]).count()
totalcasos.head()
# Out:
#                             Total
# ENTIDAD_NAC         SEXO
# Aguascalientes      Hombre    199
#                     Mujer     150
# Baja California     Hombre    920
#                     Mujer     607
# Baja California Sur Hombre    100

# %% [markdown]
# ## 5.10 Merge Dataframes     <a id='id10'> </a>
#
# - **pandas** tiene operaciones de **combinación de dataframes** en memoria de alto rendimiento muy similares a las bases de datos relacionales como SQL.
# - **pandas** proporciona una sola función, **merge()**, como punto de entrada para todas las operaciones de combinación de bases de datos entre DataFrames.
#
# Las operaciones de combinación entre dos DataFrames se debe considerar lo siguiente:
#
# - **Uniones uno a uno**: por ejemplo, cuando se unen dos objetos DataFrame en sus índices (que deben contener valores únicos).
# - **Uniones de muchos a uno**: por ejemplo, cuando se une un índice (único) a una o más columnas en un DataFrame diferente.
# - **Uniones de muchos a muchos** : unión de columnas sobre columnas!
#
# ### how
# - El argumento **how** para fusionar los dataframes sirve para determinar qué claves se incluirán en la tabla resultante.
# - Si una combinación de índices (keys) no aparece en las tablas izquierda o derecha, los valores en la tabla unida serán NA.
#
# ![](PandasMerge.png)

# %%
#df_catalogo_sector = pd.read_excel('Catalogos_covid.xlsx',
#                       sheet_name = 'Catálogo SEXO',
#                      skiprows =range(20),
#                      skipfooter=2 )

df_catalogo_sexo = pd.read_excel('Catalogos_covid.xlsx',
                       sheet_name = 'Catálogo SEXO' )
df_catalogo_sexo
# Out:
#    CLAVE      DESCRIPCIÓN
# 0      1            MUJER
# 1      2           HOMBRE
# 2     99  NO ESPECIFICADO

# %%
df_catalogo_tipopaciente = pd.read_excel('Catalogos_covid.xlsx',
                       sheet_name = 'Catálogo TIPO_PACIENTE' )
df_catalogo_tipopaciente
# Out:
#    CLAVE      DESCRIPCIÓN
# 0      1      AMBULATORIO
# 1      2    HOSPITALIZADO
# 2     99  NO ESPECIFICADO

# %%
df_catalogo_entidades = pd.read_excel('Catalogos_covid.xlsx',
                       sheet_name = 'Catálogo de ENTIDADES' )
df_catalogo_entidades.head()
# Out:
#    CLAVE_ENTIDAD    ENTIDAD_FEDERATIVA ABREVIATURA
# 0              1        AGUASCALIENTES          AS
# 1              2       BAJA CALIFORNIA          BC
# 2              3   BAJA CALIFORNIA SUR          BS
# 3              4              CAMPECHE          CC
# 4              5  COAHUILA DE ZARAGOZA          CL

# %%
df_catalogo_resultado = pd.read_excel('Catalogos_covid.xlsx',
                       sheet_name = 'Catálogo RESULTADO' )
df_catalogo_resultado.head()
# Out:
#    CLAVE             DESCRIPCIÓN
# 0      1     Positivo SARS-CoV-2
# 1      2  No positivo SARS-CoV-2
# 2      3     Resultado pendiente

# %%
covid2 = pd.read_csv("20-07-31-COVID19MEXICO.csv", encoding = 'ISO-8859-1')
covid2
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-07-31      1765cb       2       3          15     2
# 1               2020-07-31      01cd82       2       3          27     2
# 2               2020-07-31      16c05d       2       3          15     2
# 3               2020-07-31      106446       2       4          15     2
# 4               2020-07-31      1162db       2       4           9     1
# ...                    ...         ...     ...     ...         ...   ...
# 984283          2020-07-31      125bb4       2      12          15     1
# 984284          2020-07-31      02101b       2      12          28     2
# 984285          2020-07-31      0f4797       2      12          25     1
# 984286          2020-07-31      13346d       2       9           8     1
# 984287          2020-07-31      16a42d       2      12          16     2
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0                15           15            118              1  ...
# 1                27           27              4              1  ...
# 2                15           15             24              1  ...
# 3                15           15            121              2  ...
# 4                15           15             58              1  ...
# ...             ...          ...            ...            ...  ...
# 984283           15           15             27              1  ...
# 984284           28           28             27              1  ...
# 984285           25           25             12              1  ...
# 984286            8            8             17              1  ...
# 984287           16           16             53              1  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 0                   2        2             2           1          1
# 1                   2        2             2           2          1
# 2                   1        2             2           2          1
# 3                   2        2             2           2         99
# 4                   2        2             2           2         99
# ...               ...      ...           ...         ...        ...
# 984283              2        1             2           2         99
# 984284              2        2             2           1          1
# 984285              2        2             2           2          2
# 984286              2        2             2           2          2
# 984287              2        2             2           2          2
#
#         RESULTADO  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0               1        99            MÃ©xico           99   97
# 1               1        99            MÃ©xico           99   97
# 2               1        99            MÃ©xico           99   97
# 3               1        99            MÃ©xico           99    2
# 4               1        99            MÃ©xico           99   97
# ...           ...       ...                ...          ...  ...
# 984283          3        99            MÃ©xico           99   97
# 984284          3        99            MÃ©xico           99   97
# 984285          3        99            MÃ©xico           99   97
# 984286          3        99            MÃ©xico           99   97
# 984287          3        99            MÃ©xico           99   97
#
# [984288 rows x 35 columns]

# %%
covidMERGE = pd.merge(covid2, df_catalogo_entidades, left_on="ENTIDAD_NAC",
                  right_on="CLAVE_ENTIDAD")

# %%
# El resultado del merge esta al final

covidMERGE
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-07-31      1765cb       2       3          15     2
# 1               2020-07-31      16c05d       2       3          15     2
# 2               2020-07-31      106446       2       4          15     2
# 3               2020-07-31      1162db       2       4           9     1
# 4               2020-07-31      04b5e9       2       4          15     2
# ...                    ...         ...     ...     ...         ...   ...
# 984283          2020-07-31      038942       2       9           8     2
# 984284          2020-07-31      18aec3       2      12           1     2
# 984285          2020-07-31      05b498       2       6          32     1
# 984286          2020-07-31      18cec8       2       6          32     2
# 984287          2020-07-31      0305fe       2      12           1     2
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0                15           15            118              1  ...
# 1                15           15             24              1  ...
# 2                15           15            121              2  ...
# 3                15           15             58              1  ...
# 4                15           15             62              2  ...
# ...             ...          ...            ...            ...  ...
# 984283           32            8             19              1  ...
# 984284           32            1              1              1  ...
# 984285           32           32             51              1  ...
# 984286           32           32             37              1  ...
# 984287           32            1              1              1  ...
#
#        TABAQUISMO OTRO_CASO RESULTADO  MIGRANTE  PAIS_NACIONALIDAD  \
# 0               1         1         1        99            MÃ©xico
# 1               2         1         1        99            MÃ©xico
# 2               2        99         1        99            MÃ©xico
# 3               2        99         1        99            MÃ©xico
# 4               2        99         1        99            MÃ©xico
# ...           ...       ...       ...       ...                ...
# 984283          2         2         3        99            MÃ©xico
# 984284          2         1         3        99            MÃ©xico
# 984285          2         2         3        99            MÃ©xico
# 984286          2         2         3        99            MÃ©xico
# 984287          2         1         3        99            MÃ©xico
#
#         PAIS_ORIGEN  UCI  CLAVE_ENTIDAD  ENTIDAD_FEDERATIVA  ABREVIATURA
# 0                99   97             15              MÉXICO           MC
# 1                99   97             15              MÉXICO           MC
# 2                99    2             15              MÉXICO           MC
# 3                99   97             15              MÉXICO           MC
# 4                99    2             15              MÉXICO           MC
# ...             ...  ...            ...                 ...          ...
# 984283           99   97             32           ZACATECAS           ZS
# 984284           99   97             32           ZACATECAS           ZS
# 984285           99   97             32           ZACATECAS           ZS
# 984286           99   97             32           ZACATECAS           ZS
# 984287           99   97             32           ZACATECAS           ZS
#
# [984288 rows x 38 columns]

# %%
covidMERGE.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'DIABETES',
#        'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'RESULTADO', 'MIGRANTE', 'PAIS_NACIONALIDAD',
#        'PAIS_ORIGEN', 'UCI', 'CLAVE_ENTIDAD', 'ENTIDAD_FEDERATIVA',
#        'ABREVIATURA'],
#       dtype='object')

# %%
#  HACEMOS 

covidMERGE = pd.merge(covidMERGE,  df_catalogo_sexo, left_on="SEXO",
                  right_on="CLAVE")

# %%
covidMERGE
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-07-31      1765cb       2       3          15     2
# 1               2020-07-31      16c05d       2       3          15     2
# 2               2020-07-31      106446       2       4          15     2
# 3               2020-07-31      04b5e9       2       4          15     2
# 4               2020-07-31      116171       2       4          15     2
# ...                    ...         ...     ...     ...         ...   ...
# 984283          2020-07-31      06451f       1       4          32     1
# 984284          2020-07-31      09010e       1      12          32     1
# 984285          2020-07-31      18ac50       1       4          32     1
# 984286          2020-07-31      090de0       1      12          32     1
# 984287          2020-07-31      05b498       2       6          32     1
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... RESULTADO  \
# 0                15           15            118              1  ...         1
# 1                15           15             24              1  ...         1
# 2                15           15            121              2  ...         1
# 3                15           15             62              2  ...         1
# 4                15           15             60              1  ...         1
# ...             ...          ...            ...            ...  ...       ...
# 984283           32           32             42              1  ...         3
# 984284           32           32             56              2  ...         3
# 984285           32           32             40              1  ...         3
# 984286           32           32             40              1  ...         3
# 984287           32           32             51              1  ...         3
#
#        MIGRANTE PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI  CLAVE_ENTIDAD  \
# 0            99           MÃ©xico           99   97             15
# 1            99           MÃ©xico           99   97             15
# 2            99           MÃ©xico           99    2             15
# 3            99           MÃ©xico           99    2             15
# 4            99           MÃ©xico           99   97             15
# ...         ...               ...          ...  ...            ...
# 984283       99           MÃ©xico           99   97             32
# 984284       99           MÃ©xico           99    1             32
# 984285       99           MÃ©xico           99   97             32
# 984286       99           MÃ©xico           99   97             32
# 984287       99           MÃ©xico           99   97             32
#
#         ENTIDAD_FEDERATIVA  ABREVIATURA  CLAVE  DESCRIPCIÓN
# 0                   MÉXICO           MC      2       HOMBRE
# 1                   MÉXICO           MC      2       HOMBRE
# 2                   MÉXICO           MC      2       HOMBRE
# 3                   MÉXICO           MC      2       HOMBRE
# 4                   MÉXICO           MC      2       HOMBRE
# ...                    ...          ...    ...          ...
# 984283           ZACATECAS           ZS      1        MUJER
# 984284           ZACATECAS           ZS      1        MUJER
# 984285           ZACATECAS           ZS      1        MUJER
# 984286           ZACATECAS           ZS      1        MUJER
# 984287           ZACATECAS           ZS      1        MUJER
#
# [984288 rows x 40 columns]

# %%
## CONSULTAMOS nuevamente LAS COLUMNAS PARA BORRRAR LAS QUE NO NECESITAMOS

# %%
covidMERGE.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'DIABETES',
#        'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'RESULTADO', 'MIGRANTE', 'PAIS_NACIONALIDAD',
#        'PAIS_ORIGEN', 'UCI', 'CLAVE_ENTIDAD', 'ENTIDAD_FEDERATIVA',
#        'ABREVIATURA', 'CLAVE', 'DESCRIPCIÓN'],
#       dtype='object')

# %%
columnas = ["FECHA_ACTUALIZACION", "ID_REGISTRO", "ORIGEN", "SECTOR", "ENTIDAD_UM", "ENTIDAD_RES", 
            "MUNICIPIO_RES", "HABLA_LENGUA_INDIG", "OTRA_COM", "OTRO_CASO", "MIGRANTE", "PAIS_ORIGEN",
           "CLAVE_ENTIDAD", "ABREVIATURA", "CLAVE"]

covidMERGE.drop(columnas, axis = 1, inplace = True)

# %%
covidMERGE
# Out:
#         SEXO  ENTIDAD_NAC  TIPO_PACIENTE FECHA_INGRESO FECHA_SINTOMAS  \
# 0          2           15              1    2020-06-12     2020-06-08
# 1          2           15              1    2020-06-20     2020-06-20
# 2          2           15              2    2020-04-20     2020-04-20
# 3          2           15              2    2020-04-13     2020-04-06
# 4          2           15              1    2020-04-15     2020-04-05
# ...      ...          ...            ...           ...            ...
# 984283     1           32              1    2020-07-30     2020-07-27
# 984284     1           32              2    2020-07-30     2020-07-25
# 984285     1           32              1    2020-07-30     2020-07-25
# 984286     1           32              1    2020-07-30     2020-07-27
# 984287     1           32              1    2020-07-28     2020-07-22
#
#          FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  ...  HIPERTENSION  \
# 0       9999-99-99        97         2    32             1  ...             2
# 1       9999-99-99        97         2    53             1  ...             2
# 2       9999-99-99         2         2    46             1  ...             2
# 3       2020-04-15         2         1    26             1  ...             2
# 4       9999-99-99        97         1    44             1  ...             2
# ...            ...       ...       ...   ...           ...  ...           ...
# 984283  9999-99-99        97         2    52             1  ...             2
# 984284  9999-99-99         2         1    67             1  ...             1
# 984285  9999-99-99        97         2    80             1  ...             2
# 984286  9999-99-99        97         2    25             1  ...             2
# 984287  9999-99-99        97         2    34             1  ...             2
#
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  RESULTADO  \
# 0                    2         2              2           1          1
# 1                    1         2              2           2          1
# 2                    2         2              2           2          1
# 3                    2         1              2           2          1
# 4                    2         2              2           2          1
# ...                ...       ...            ...         ...        ...
# 984283               2         2              2           2          3
# 984284               2         2              2           2          3
# 984285               2         1              2           2          3
# 984286               2         2              2           2          3
# 984287               2         2              2           2          3
#
#         PAIS_NACIONALIDAD  UCI  ENTIDAD_FEDERATIVA  DESCRIPCIÓN
# 0                 MÃ©xico   97              MÉXICO       HOMBRE
# 1                 MÃ©xico   97              MÉXICO       HOMBRE
# 2                 MÃ©xico    2              MÉXICO       HOMBRE
# 3                 MÃ©xico    2              MÉXICO       HOMBRE
# 4                 MÃ©xico   97              MÉXICO       HOMBRE
# ...                   ...  ...                 ...          ...
# 984283            MÃ©xico   97           ZACATECAS        MUJER
# 984284            MÃ©xico    1           ZACATECAS        MUJER
# 984285            MÃ©xico   97           ZACATECAS        MUJER
# 984286            MÃ©xico   97           ZACATECAS        MUJER
# 984287            MÃ©xico   97           ZACATECAS        MUJER
#
# [984288 rows x 25 columns]

# %%
covidMERGE.columns
# Out:
# Index(['SEXO', 'ENTIDAD_NAC', 'TIPO_PACIENTE', 'FECHA_INGRESO',
#        'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA', 'EDAD',
#        'NACIONALIDAD', 'EMBARAZO', 'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR',
#        'HIPERTENSION', 'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA',
#        'TABAQUISMO', 'RESULTADO', 'PAIS_NACIONALIDAD', 'UCI',
#        'ENTIDAD_FEDERATIVA', 'DESCRIPCIÓN'],
#       dtype='object')

# %%
# Ahora hacemos la union con el catalogo de tipo paciente

covidMERGE = pd.merge(covidMERGE,  df_catalogo_tipopaciente, left_on="TIPO_PACIENTE",
                  right_on="CLAVE")
covidMERGE
# Out:
#         SEXO  ENTIDAD_NAC  TIPO_PACIENTE FECHA_INGRESO FECHA_SINTOMAS  \
# 0          2           15              1    2020-06-12     2020-06-08
# 1          2           15              1    2020-06-20     2020-06-20
# 2          2           15              1    2020-04-15     2020-04-05
# 3          2           15              1    2020-06-15     2020-06-10
# 4          2           15              1    2020-04-27     2020-04-27
# ...      ...          ...            ...           ...            ...
# 984283     1           32              2    2020-07-27     2020-07-23
# 984284     1           32              2    2020-07-30     2020-07-26
# 984285     1           32              2    2020-07-28     2020-07-25
# 984286     1           32              2    2020-07-06     2020-07-06
# 984287     1           32              2    2020-07-30     2020-07-25
#
#          FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  ...  OBESIDAD  \
# 0       9999-99-99        97         2    32             1  ...         2
# 1       9999-99-99        97         2    53             1  ...         2
# 2       9999-99-99        97         1    44             1  ...         2
# 3       9999-99-99        97         1    48             1  ...         2
# 4       9999-99-99        97         2    28             1  ...         2
# ...            ...       ...       ...   ...           ...  ...       ...
# 984283  9999-99-99         2         2    67             1  ...         2
# 984284  9999-99-99         2         2    81             1  ...         2
# 984285  9999-99-99         2         2    52             1  ...         2
# 984286  9999-99-99         2         2    48             1  ...         2
# 984287  9999-99-99         2         1    67             1  ...         2
#
#         RENAL_CRONICA  TABAQUISMO  RESULTADO  PAIS_NACIONALIDAD  UCI  \
# 0                   2           1          1            MÃ©xico   97
# 1                   2           2          1            MÃ©xico   97
# 2                   2           2          1            MÃ©xico   97
# 3                   2           2          1            MÃ©xico   97
# 4                   2           2          1            MÃ©xico   97
# ...               ...         ...        ...                ...  ...
# 984283              2           2          3            MÃ©xico    2
# 984284              2           1          3            MÃ©xico    2
# 984285              2           2          3            MÃ©xico    2
# 984286              2           2          3            MÃ©xico    2
# 984287              2           2          3            MÃ©xico    1
#
#         ENTIDAD_FEDERATIVA  DESCRIPCIÓN_x  CLAVE  DESCRIPCIÓN_y
# 0                   MÉXICO         HOMBRE      1    AMBULATORIO
# 1                   MÉXICO         HOMBRE      1    AMBULATORIO
# 2                   MÉXICO         HOMBRE      1    AMBULATORIO
# 3                   MÉXICO         HOMBRE      1    AMBULATORIO
# 4                   MÉXICO         HOMBRE      1    AMBULATORIO
# ...                    ...            ...    ...            ...
# 984283           ZACATECAS          MUJER      2  HOSPITALIZADO
# 984284           ZACATECAS          MUJER      2  HOSPITALIZADO
# 984285           ZACATECAS          MUJER      2  HOSPITALIZADO
# 984286           ZACATECAS          MUJER      2  HOSPITALIZADO
# 984287           ZACATECAS          MUJER      2  HOSPITALIZADO
#
# [984288 rows x 27 columns]

# %%
columnas = ["ENTIDAD_NAC", "SEXO", "TIPO_PACIENTE"]

covidMERGE.drop(columnas, axis = 1, inplace = True)

# %%
covidMERGE
# Out:
#        FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 0         2020-06-12     2020-06-08  9999-99-99        97         2    32
# 1         2020-06-20     2020-06-20  9999-99-99        97         2    53
# 2         2020-04-15     2020-04-05  9999-99-99        97         1    44
# 3         2020-06-15     2020-06-10  9999-99-99        97         1    48
# 4         2020-04-27     2020-04-27  9999-99-99        97         2    28
# ...              ...            ...         ...       ...       ...   ...
# 984283    2020-07-27     2020-07-23  9999-99-99         2         2    67
# 984284    2020-07-30     2020-07-26  9999-99-99         2         2    81
# 984285    2020-07-28     2020-07-25  9999-99-99         2         2    52
# 984286    2020-07-06     2020-07-06  9999-99-99         2         2    48
# 984287    2020-07-30     2020-07-25  9999-99-99         2         1    67
#
#         NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ...  OBESIDAD  RENAL_CRONICA  \
# 0                  1        97         2     2  ...         2              2
# 1                  1        97         2     2  ...         2              2
# 2                  1        97         2     2  ...         2              2
# 3                  1        97         2     2  ...         2              2
# 4                  1        97         2     2  ...         2              2
# ...              ...       ...       ...   ...  ...       ...            ...
# 984283             1         2         2     2  ...         2              2
# 984284             1         2         1     1  ...         2              2
# 984285             1         2         1     2  ...         2              2
# 984286             1         2         2     2  ...         2              2
# 984287             1         2         1     2  ...         2              2
#
#         TABAQUISMO  RESULTADO  PAIS_NACIONALIDAD  UCI  ENTIDAD_FEDERATIVA  \
# 0                1          1            MÃ©xico   97              MÉXICO
# 1                2          1            MÃ©xico   97              MÉXICO
# 2                2          1            MÃ©xico   97              MÉXICO
# 3                2          1            MÃ©xico   97              MÉXICO
# 4                2          1            MÃ©xico   97              MÉXICO
# ...            ...        ...                ...  ...                 ...
# 984283           2          3            MÃ©xico    2           ZACATECAS
# 984284           1          3            MÃ©xico    2           ZACATECAS
# 984285           2          3            MÃ©xico    2           ZACATECAS
# 984286           2          3            MÃ©xico    2           ZACATECAS
# 984287           2          3            MÃ©xico    1           ZACATECAS
#
#         DESCRIPCIÓN_x CLAVE  DESCRIPCIÓN_y
# 0              HOMBRE     1    AMBULATORIO
# 1              HOMBRE     1    AMBULATORIO
# 2              HOMBRE     1    AMBULATORIO
# 3              HOMBRE     1    AMBULATORIO
# 4              HOMBRE     1    AMBULATORIO
# ...               ...   ...            ...
# 984283          MUJER     2  HOSPITALIZADO
# 984284          MUJER     2  HOSPITALIZADO
# 984285          MUJER     2  HOSPITALIZADO
# 984286          MUJER     2  HOSPITALIZADO
# 984287          MUJER     2  HOSPITALIZADO
#
# [984288 rows x 24 columns]

# %%
covidMERGE.columns
# Out:
# Index(['FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'DIABETES', 'EPOC', 'ASMA',
#        'INMUSUPR', 'HIPERTENSION', 'CARDIOVASCULAR', 'OBESIDAD',
#        'RENAL_CRONICA', 'TABAQUISMO', 'RESULTADO', 'PAIS_NACIONALIDAD', 'UCI',
#        'ENTIDAD_FEDERATIVA', 'DESCRIPCIÓN_x', 'CLAVE', 'DESCRIPCIÓN_y'],
#       dtype='object')

# %%
# RENOMBRAR LAS COLUMNAS CON UN NOMBRE MAS ADECUADO 

covidMERGE.rename(columns={"DESCRIPCIÓN_x": "SEXO", "DESCRIPCIÓN_y": "TIPO_PACIENTE"}, inplace = True)
covidMERGE
# Out:
#        FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 0         2020-06-12     2020-06-08  9999-99-99        97         2    32
# 1         2020-06-20     2020-06-20  9999-99-99        97         2    53
# 2         2020-04-15     2020-04-05  9999-99-99        97         1    44
# 3         2020-06-15     2020-06-10  9999-99-99        97         1    48
# 4         2020-04-27     2020-04-27  9999-99-99        97         2    28
# ...              ...            ...         ...       ...       ...   ...
# 984283    2020-07-27     2020-07-23  9999-99-99         2         2    67
# 984284    2020-07-30     2020-07-26  9999-99-99         2         2    81
# 984285    2020-07-28     2020-07-25  9999-99-99         2         2    52
# 984286    2020-07-06     2020-07-06  9999-99-99         2         2    48
# 984287    2020-07-30     2020-07-25  9999-99-99         2         1    67
#
#         NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ...  OBESIDAD  RENAL_CRONICA  \
# 0                  1        97         2     2  ...         2              2
# 1                  1        97         2     2  ...         2              2
# 2                  1        97         2     2  ...         2              2
# 3                  1        97         2     2  ...         2              2
# 4                  1        97         2     2  ...         2              2
# ...              ...       ...       ...   ...  ...       ...            ...
# 984283             1         2         2     2  ...         2              2
# 984284             1         2         1     1  ...         2              2
# 984285             1         2         1     2  ...         2              2
# 984286             1         2         2     2  ...         2              2
# 984287             1         2         1     2  ...         2              2
#
#         TABAQUISMO  RESULTADO  PAIS_NACIONALIDAD  UCI  ENTIDAD_FEDERATIVA  \
# 0                1          1            MÃ©xico   97              MÉXICO
# 1                2          1            MÃ©xico   97              MÉXICO
# 2                2          1            MÃ©xico   97              MÉXICO
# 3                2          1            MÃ©xico   97              MÉXICO
# 4                2          1            MÃ©xico   97              MÉXICO
# ...            ...        ...                ...  ...                 ...
# 984283           2          3            MÃ©xico    2           ZACATECAS
# 984284           1          3            MÃ©xico    2           ZACATECAS
# 984285           2          3            MÃ©xico    2           ZACATECAS
# 984286           2          3            MÃ©xico    2           ZACATECAS
# 984287           2          3            MÃ©xico    1           ZACATECAS
#
#           SEXO CLAVE  TIPO_PACIENTE
# 0       HOMBRE     1    AMBULATORIO
# 1       HOMBRE     1    AMBULATORIO
# 2       HOMBRE     1    AMBULATORIO
# 3       HOMBRE     1    AMBULATORIO
# 4       HOMBRE     1    AMBULATORIO
# ...        ...   ...            ...
# 984283   MUJER     2  HOSPITALIZADO
# 984284   MUJER     2  HOSPITALIZADO
# 984285   MUJER     2  HOSPITALIZADO
# 984286   MUJER     2  HOSPITALIZADO
# 984287   MUJER     2  HOSPITALIZADO
#
# [984288 rows x 24 columns]

# %% [markdown]
# ## 5.11 Exportar Dataframe a csv      <a id='id11'> </a>

# %%
# Exportar dataframe a un archivo csv los registros que cumplan los siguientes criterios de
# seleccion de registros


PruebasDgo = df[ ( df['ENTIDAD_NAC'] == "Durango") & ( df['TIPO_PACIENTE'] == "Hospitalizado") &
             ( df['RESULTADO'] == "Positivo") ]
PruebasDgo
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 845591          31/07/2020      0bdf07  ISSSTE       3          25  Hombre
# 845592          31/07/2020      0b99e5  ISSSTE       4           9   Mujer
# 845593          31/07/2020      19c52b  ISSSTE       4           2  Hombre
# 845594          31/07/2020      0c2d53  ISSSTE       4           8   Mujer
# 845595          31/07/2020      108217  ISSSTE       4           2  Hombre
# ...                    ...         ...     ...     ...         ...     ...
# 847592          31/07/2020      1d09e5       1       4          10  Hombre
# 847593          31/07/2020      0bb65a  ISSSTE       4          10  Hombre
# 847594          31/07/2020      0199c0       1      12           2  Hombre
# 847595          31/07/2020      0cfa6a  ISSSTE       4           5   Mujer
# 847596          31/07/2020      1cb211  ISSSTE       4          10  Hombre
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OBESIDAD  \
# 845591     Durango           25              6  Hospitalizado  ...       Si
# 845592     Durango           15             58  Hospitalizado  ...       No
# 845593     Durango            2              4  Hospitalizado  ...       No
# 845594     Durango            8             37  Hospitalizado  ...       No
# 845595     Durango            2              2  Hospitalizado  ...       No
# ...            ...          ...            ...            ...  ...      ...
# 847592     Durango           10              7  Hospitalizado  ...       No
# 847593     Durango           10              7  Hospitalizado  ...       Si
# 847594     Durango            2              2  Hospitalizado  ...       No
# 847595     Durango           10              7  Hospitalizado  ...       No
# 847596     Durango           10              7  Hospitalizado  ...       No
#
#        RENAL_CRONICA TABAQUISMO        OTRO_CASO RESULTADO  MIGRANTE  \
# 845591            No         No  No especificado  Positivo        99
# 845592            No         No  No especificado  Positivo        99
# 845593            No         No  No especificado  Positivo        99
# 845594            No         No  No especificado  Positivo        99
# 845595            No         No  No especificado  Positivo        99
# ...              ...        ...              ...       ...       ...
# 847592            No         No  No especificado  Positivo        99
# 847593            No         No  No especificado  Positivo        99
# 847594            No         No               Si  Positivo        99
# 847595            No         No  No especificado  Positivo        99
# 847596            No         No  No especificado  Positivo        99
#
#         PAIS_NACIONALIDAD PAIS_ORIGEN UCI Total
# 845591            MÃ©xico          99  No     0
# 845592            MÃ©xico          99  No     0
# 845593            MÃ©xico          99  No     0
# 845594            MÃ©xico          99  No     0
# 845595            MÃ©xico          99  No     0
# ...                   ...         ...  ..   ...
# 847592            MÃ©xico          99  No     0
# 847593            MÃ©xico          99  No     0
# 847594            MÃ©xico          99  No     0
# 847595            MÃ©xico          99  No     0
# 847596            MÃ©xico          99  No     0
#
# [1080 rows x 36 columns]

# %%
PruebasDgo.to_csv("Positivos Durango Hospitalizados.csv")

# %%
# Quitar el indice del archivo generado

PruebasDgo.to_csv("mujeres.csv", index = False)

# %% [markdown]
# ## 5.12  PIVOT  Tables   <a id='id12'> </a>
#
# Devuelve el DataFrame remodelado organizado por los valores de índice/columna especificados.
#
# - Remodele los datos (produzca una tabla "pivote") en función de los valores de las columnas.
# - Utiliza valores únicos de índices/columnas especificados para formar ejes del DataFrame resultante.
# - Esta función no admite la agregación de datos, varios valores darán como resultado un índice múltiple en las columnas.
#
# ![](Pivot.png)

# %%
# Verificamos como estan los datos actualmente

covidMERGE.head()
# Out:
#   FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 0    2020-06-12     2020-06-08  9999-99-99        97         2    32
# 1    2020-06-20     2020-06-20  9999-99-99        97         2    53
# 2    2020-04-15     2020-04-05  9999-99-99        97         1    44
# 3    2020-06-15     2020-06-10  9999-99-99        97         1    48
# 4    2020-04-27     2020-04-27  9999-99-99        97         2    28
#
#    NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ...  OBESIDAD  RENAL_CRONICA  \
# 0             1        97         2     2  ...         2              2
# 1             1        97         2     2  ...         2              2
# 2             1        97         2     2  ...         2              2
# 3             1        97         2     2  ...         2              2
# 4             1        97         2     2  ...         2              2
#
#    TABAQUISMO  RESULTADO  PAIS_NACIONALIDAD  UCI  ENTIDAD_FEDERATIVA    SEXO  \
# 0           1          1            MÃ©xico   97              MÉXICO  HOMBRE
# 1           2          1            MÃ©xico   97              MÉXICO  HOMBRE
# 2           2          1            MÃ©xico   97              MÉXICO  HOMBRE
# 3           2          1            MÃ©xico   97              MÉXICO  HOMBRE
# 4           2          1            MÃ©xico   97              MÉXICO  HOMBRE
#
#   CLAVE  TIPO_PACIENTE
# 0     1    AMBULATORIO
# 1     1    AMBULATORIO
# 2     1    AMBULATORIO
# 3     1    AMBULATORIO
# 4     1    AMBULATORIO
#
# [5 rows x 24 columns]

# %%
# Realizamos la tabla pivote o tabla dinamica

covidMERGE.pivot_table( values= 'RESULTADO' , index='ENTIDAD_FEDERATIVA', columns='TIPO_PACIENTE', aggfunc=np.size)
# Out:
# TIPO_PACIENTE                    AMBULATORIO  HOSPITALIZADO
# ENTIDAD_FEDERATIVA
# AGUASCALIENTES                          9400           1472
# BAJA CALIFORNIA                        10703           3578
# BAJA CALIFORNIA SUR                     6298            774
# CAMPECHE                                5686           1755
# CHIAPAS                                 8930           3681
# CHIHUAHUA                               8035           3527
# CIUDAD DE MÉXICO                      176473          31241
# COAHUILA DE ZARAGOZA                   31537           3814
# COLIMA                                  2381            739
# DURANGO                                12199           2352
# GUANAJUATO                             43510           7113
# GUERRERO                               19407           5594
# HIDALGO                                 9641           3919
# JALISCO                                30755           8548
# MICHOACÁN DE OCAMPO                    25915           5170
# MORELOS                                 5523           2725
# MÉXICO                                 86330          25906
# NAYARIT                                 5481           1725
# NO ESPECIFICADO                         4274            604
# NUEVO LEÓN                             35503           5811
# OAXACA                                 17275           5923
# PUEBLA                                 33306          10348
# QUERÉTARO                               3603           1925
# QUINTANA ROO                            5340           1108
# SAN LUIS POTOSÍ                        22667           3942
# SINALOA                                20156           7545
# SONORA                                 20895           6108
# TABASCO                                34612           5061
# TAMAULIPAS                             32843           5102
# TLAXCALA                               10209           2795
# VERACRUZ DE IGNACIO DE LA LLAVE        32413          13606
# YUCATÁN                                16373           4113
# ZACATECAS                               6733           2258

# %%
# Realizamos la tabla pivote o tabla dinamica

covidMERGE.pivot_table( values= 'RESULTADO' , index='ENTIDAD_FEDERATIVA', columns='SEXO', aggfunc=np.size)
# Out:
# SEXO                             HOMBRE   MUJER
# ENTIDAD_FEDERATIVA
# AGUASCALIENTES                     4972    5900
# BAJA CALIFORNIA                    6889    7392
# BAJA CALIFORNIA SUR                3272    3800
# CAMPECHE                           4130    3311
# CHIAPAS                            6993    5618
# CHIHUAHUA                          5564    5998
# CIUDAD DE MÉXICO                 102812  104902
# COAHUILA DE ZARAGOZA              16926   18425
# COLIMA                             1495    1625
# DURANGO                            6797    7754
# GUANAJUATO                        24037   26586
# GUERRERO                          12899   12102
# HIDALGO                            7091    6469
# JALISCO                           19048   20255
# MICHOACÁN DE OCAMPO               15270   15815
# MORELOS                            4182    4066
# MÉXICO                            56169   56067
# NAYARIT                            3511    3695
# NO ESPECIFICADO                    2720    2158
# NUEVO LEÓN                        20236   21078
# OAXACA                            12473   10725
# PUEBLA                            22396   21258
# QUERÉTARO                          2749    2779
# QUINTANA ROO                       3281    3167
# SAN LUIS POTOSÍ                   12884   13725
# SINALOA                           13401   14300
# SONORA                            12553   14450
# TABASCO                           19835   19838
# TAMAULIPAS                        19375   18570
# TLAXCALA                           6518    6486
# VERACRUZ DE IGNACIO DE LA LLAVE   25119   20900
# YUCATÁN                           11129    9357
# ZACATECAS                          4465    4526

# %%
# Realizamos la tabla pivote o tabla dinamica

covidMERGE.pivot_table( values= 'RESULTADO' , index='ENTIDAD_FEDERATIVA', columns='SEXO', aggfunc=np.size)

# %% [markdown]
# ## 5.12 Valores perdidos   <a id='id12'> </a>
#
# ## PENDIENTE

# %%
import pandas as pd

# conjunto de datos de la recopilación de la página  Humanitarian Data Exchange.
# Esta página web es un excelente recurso para personas interesadas en explorar datos
# relacionados con inquietudes humanitarias internacionales.

# https://data.humdata.org/dataset/wfp-food-prices-for-mexico


df2  = pd.read_csv("wfp_food_prices_mex.csv")
df2

# %% [markdown]
# ## 5.13 Leer archivo de Excel   <a id='id13'> </a>
#
# Instalar librería  **xlrd**:
#
# - pip install xlrd
# - conda install -c anaconda xlrd
# - Entorno gráfico de Anaconda

# %%
DiagnosticoIMCO = pd.read_excel('DiagnosticoIMCO.xlsx',
                       sheet_name = 'IMCO',
                      skiprows =range(6),
                      skipfooter=2 )


DiagnosticoIMCO.head()
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
# 4              Chiapas            48873000000               27819000000
#
#    RecaudacionImpuestos        Region
# 0            1232000000  Centro-Norte
# 1            4341000000      Noroeste
# 2            1112000000      Noroeste
# 3            1663000000       Sureste
# 4            1478000000      SurOeste

# %% [markdown]
# ## 5.14 Convertir tipos de datos   <a id='id14'> </a>
#
# - Convertir de Object a Datetime
# - Convertir de Object a Int
# - Convertir de Object a Float

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984288 entries, 0 to 984287
# Data columns (total 36 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  984288 non-null  object
#  1   ID_REGISTRO          984288 non-null  object
#  2   ORIGEN               984288 non-null  object
#  3   SECTOR               984288 non-null  int64
#  4   ENTIDAD_UM           984288 non-null  int64
#  5   SEXO                 984288 non-null  object
#  6   ENTIDAD_NAC          984288 non-null  object
#  7   ENTIDAD_RES          984288 non-null  int64
#  8   MUNICIPIO_RES        984288 non-null  int64
#  9   TIPO_PACIENTE        984288 non-null  object
#  10  FECHA_INGRESO        984288 non-null  datetime64[ns]
#  11  FECHA_SINTOMAS       984288 non-null  object
#  12  FECHA_DEF            984288 non-null  object
#  13  INTUBADO             984288 non-null  object
#  14  NEUMONIA             984288 non-null  object
#  15  EDAD                 984288 non-null  int64
#  16  NACIONALIDAD         984288 non-null  int64
#  17  EMBARAZO             984288 non-null  object
#  18  HABLA_LENGUA_INDIG   984288 non-null  object
#  19  DIABETES             984288 non-null  object
#  20  EPOC                 984288 non-null  object
#  21  ASMA                 984288 non-null  object
#  22  INMUSUPR             984288 non-null  object
#  23  HIPERTENSION         984288 non-null  object
#  24  OTRA_COM             984288 non-null  object
#  25  CARDIOVASCULAR       984288 non-null  object
#  26  OBESIDAD             984288 non-null  object
#  27  RENAL_CRONICA        984288 non-null  object
#  28  TABAQUISMO           984288 non-null  object
#  29  OTRO_CASO            984288 non-null  object
#  30  RESULTADO            984288 non-null  object
#  31  MIGRANTE             984288 non-null  int64
#  32  PAIS_NACIONALIDAD    984288 non-null  object
#  33  PAIS_ORIGEN          984288 non-null  object
#  34  UCI                  984288 non-null  object
#  35  Total                984288 non-null  int64
# dtypes: datetime64[ns](1), int64(8), object(27)
# memory usage: 270.3+ MB

# %%
# En dataframe del COVID las fechas aparecen como tipo object

df['FECHA_SINTOMAS'] = pd.to_datetime(df['FECHA_SINTOMAS'], format="%d/%m/%Y")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984288 entries, 0 to 984287
# Data columns (total 36 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  984288 non-null  object
#  1   ID_REGISTRO          984288 non-null  object
#  2   ORIGEN               984288 non-null  object
#  3   SECTOR               984288 non-null  int64
#  4   ENTIDAD_UM           984288 non-null  int64
#  5   SEXO                 984288 non-null  object
#  6   ENTIDAD_NAC          984288 non-null  object
#  7   ENTIDAD_RES          984288 non-null  int64
#  8   MUNICIPIO_RES        984288 non-null  int64
#  9   TIPO_PACIENTE        984288 non-null  object
#  10  FECHA_INGRESO        984288 non-null  datetime64[ns]
#  11  FECHA_SINTOMAS       984288 non-null  datetime64[ns]
#  12  FECHA_DEF            984288 non-null  object
#  13  INTUBADO             984288 non-null  object
#  14  NEUMONIA             984288 non-null  object
#  15  EDAD                 984288 non-null  int64
#  16  NACIONALIDAD         984288 non-null  int64
#  17  EMBARAZO             984288 non-null  object
#  18  HABLA_LENGUA_INDIG   984288 non-null  object
#  19  DIABETES             984288 non-null  object
#  20  EPOC                 984288 non-null  object
#  21  ASMA                 984288 non-null  object
#  22  INMUSUPR             984288 non-null  object
#  23  HIPERTENSION         984288 non-null  object
#  24  OTRA_COM             984288 non-null  object
#  25  CARDIOVASCULAR       984288 non-null  object
#  26  OBESIDAD             984288 non-null  object
#  27  RENAL_CRONICA        984288 non-null  object
#  28  TABAQUISMO           984288 non-null  object
#  29  OTRO_CASO            984288 non-null  object
#  30  RESULTADO            984288 non-null  object
#  31  MIGRANTE             984288 non-null  int64
#  32  PAIS_NACIONALIDAD    984288 non-null  object
#  33  PAIS_ORIGEN          984288 non-null  object
#  34  UCI                  984288 non-null  object
#  35  Total                984288 non-null  int64
# dtypes: datetime64[ns](2), int64(8), object(26)
# memory usage: 270.3+ MB

# %% [markdown]
# ## 5.15 Formatting the Display Dataframe  <a id='id15'> </a>
#
# Antes de agregar estilos, es útil mostrar que Styler puede distinguir el valor de visualización del valor real, tanto en valores de datos como en encabezados de índice o columnas.
# - Para controlar el valor de visualización, el texto se imprime en cada celda como una cadena, y podemos usar los métodos .format() y .format_index() para manipular esto de acuerdo con una cadena de especificación de formato o un invocable que toma un valor único y devuelve un String.
# - Es posible definir esto para toda la tabla o índice, o para columnas individuales o niveles MultiIndex.
#
# - Además, la función de formato tiene un argumento de precisión para ayudar específicamente a dar formato a los flotantes, así como separadores decimales y de miles para admitir otras configuraciones regionales,
# - un argumento na_rep para mostrar los datos que faltan
# - un argumento de escape para ayudar a mostrar HTML seguro o LaTeX seguro.
# - El formateador predeterminado está configurado para adoptar la opción **styler.format.precision** de pandas, controlable mediante **pd.option_context('format.precision', 2):**
#
# **Fuente:**
# https://pandas.pydata.org/docs/user_guide/style.html

# %%
DiagnosticoIMCO.head()

# %%
DiagnosticoIMCO.head(10).style.format(precision=0, thousands="," , 
                              formatter= {( "AportacionesFederales"): lambda x: "$ {:,.2f}".format(x), 
                                          ( "ParticipacionesFederales"): lambda x: "$ {:,.2f}".format(x),
                                          ( "RecaudacionImpuestos"): lambda x: "$ {:,.1f}".format(x)
                              })

# %%
DiagnosticoIMCO.dtypes

# %%
def make_pretty(styler):
    styler.set_caption("Distribución de Ingresos por estado")
    #styler.background_gradient(axis=None, vmin=1, vmax=2, cmap="YlGnBu")
    return styler

DiagnosticoIMCO.head(10).style.pipe(make_pretty)

# %%
import pandas as pd
covid2 = pd.read_csv("20-07-31-COVID19MEXICO.csv", encoding = 'ISO-8859-1')
covid2.head()
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-07-31      1765cb       2       3          15     2
# 1               2020-07-31      01cd82       2       3          27     2
# 2               2020-07-31      16c05d       2       3          15     2
# 3               2020-07-31      106446       2       4          15     2
# 4               2020-07-31      1162db       2       4           9     1
# ...                    ...         ...     ...     ...         ...   ...
# 984283          2020-07-31      125bb4       2      12          15     1
# 984284          2020-07-31      02101b       2      12          28     2
# 984285          2020-07-31      0f4797       2      12          25     1
# 984286          2020-07-31      13346d       2       9           8     1
# 984287          2020-07-31      16a42d       2      12          16     2
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0                15           15            118              1  ...
# 1                27           27              4              1  ...
# 2                15           15             24              1  ...
# 3                15           15            121              2  ...
# 4                15           15             58              1  ...
# ...             ...          ...            ...            ...  ...
# 984283           15           15             27              1  ...
# 984284           28           28             27              1  ...
# 984285           25           25             12              1  ...
# 984286            8            8             17              1  ...
# 984287           16           16             53              1  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 0                   2        2             2           1          1
# 1                   2        2             2           2          1
# 2                   1        2             2           2          1
# 3                   2        2             2           2         99
# 4                   2        2             2           2         99
# ...               ...      ...           ...         ...        ...
# 984283              2        1             2           2         99
# 984284              2        2             2           1          1
# 984285              2        2             2           2          2
# 984286              2        2             2           2          2
# 984287              2        2             2           2          2
#
#         RESULTADO  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0               1        99            MÃ©xico           99   97
# 1               1        99            MÃ©xico           99   97
# 2               1        99            MÃ©xico           99   97
# 3               1        99            MÃ©xico           99    2
# 4               1        99            MÃ©xico           99   97
# ...           ...       ...                ...          ...  ...
# 984283          3        99            MÃ©xico           99   97
# 984284          3        99            MÃ©xico           99   97
# 984285          3        99            MÃ©xico           99   97
# 984286          3        99            MÃ©xico           99   97
# 984287          3        99            MÃ©xico           99   97
#
# [984288 rows x 35 columns]

# %%
mapping_dict = {1: "Mujer", 2:"Hombre"}
covid2['SEXO'] = covid2['SEXO'].map(mapping_dict)

# %%
covid2.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 0          2020-07-31      1765cb       2       3          15  Hombre
# 1          2020-07-31      01cd82       2       3          27  Hombre
# 2          2020-07-31      16c05d       2       3          15  Hombre
# 3          2020-07-31      106446       2       4          15  Hombre
# 4          2020-07-31      1162db       2       4           9   Mujer
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... CARDIOVASCULAR  \
# 0           15           15            118              1  ...              2
# 1           27           27              4              1  ...              2
# 2           15           15             24              1  ...              1
# 3           15           15            121              2  ...              2
# 4           15           15             58              1  ...              2
#
#   OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  RESULTADO  MIGRANTE  \
# 0        2             2           1          1          1        99
# 1        2             2           2          1          1        99
# 2        2             2           2          1          1        99
# 3        2             2           2         99          1        99
# 4        2             2           2         99          1        99
#
#    PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0            MÃ©xico           99   97
# 1            MÃ©xico           99   97
# 2            MÃ©xico           99   97
# 3            MÃ©xico           99    2
# 4            MÃ©xico           99   97
#
# [5 rows x 35 columns]
